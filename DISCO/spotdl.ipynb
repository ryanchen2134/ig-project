# %%
! spotdl download 'Lady Gaga, Bruno Mars - Die with a smile' --format wav --output 'audio/{artist}-{title}'
# Out:
# Processing query: Lady Gaga, Bruno Mars - Die with a smile
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# Lady Gaga - Die With A   Processing         ━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# ...
