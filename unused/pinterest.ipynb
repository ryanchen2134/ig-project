# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.29.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from selenium) (0.12.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydrive
# Out:
# Requirement already satisfied: pydrive in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydrive) (2.162.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydrive) (6.0.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (2.24.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (4.1.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from oauth2client>=4.0.0->pydrive) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from oauth2client>=4.0.0->pydrive) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from oauth2client>=4.0.0->pydrive) (4.9)
# Requirement already satisfied: six>=1.6.1 in /Users/chaewonbang/Library/Python/3.12/lib/python/site-packages (from oauth2client>=4.0.0->pydrive) (1.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (1.68.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (1.26.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=1.2->pydrive) (5.5.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.2->pydrive) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2025.1.31)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import StaleElementReferenceException

# %%
# Set up directory for saving images
folder_name = "tropical vacation"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Scroll settings
sleepTime = 7  # Increase to allow images to load
max_scrolls = 50  # Prevent infinite loops
max_images = 150  # Target number of images

# Pinterest URL
var = 'vacation poses'
url = f'https://www.pinterest.com/search/pins/?q={var}'

# Set up Chrome options
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])

# Start WebDriver
service = Service("/opt/homebrew/bin/chromedriver")  # Update this path if needed
driver = webdriver.Chrome(service=service, options=options)

# Open the webpage
driver.get(url)
time.sleep(5)  # Allow time for page to load

# Scrolling logic with user interaction
image_urls = set()
scroll_attempts = 0

while len(image_urls) < max_images and scroll_attempts < max_scrolls:
    # Scroll all the way down
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(sleepTime)

    # Simulate user interaction (hovering over an image)
    images = driver.find_elements(By.TAG_NAME, "img")
    if images:
        hover = ActionChains(driver).move_to_element(images[-1])  # Hover over the last image
        hover.perform()
        time.sleep(2)  # Give time for new content to load

    # Refresh image elements
    try:
        images = driver.find_elements(By.TAG_NAME, "img")
        for img in images:
            src = img.get_attribute('src')
            if src and 'pinimg.com' in src:
                image_urls.add(src)
    except StaleElementReferenceException:
        print("Encountered stale element, skipping this batch.")

    print(f'Scrolling... Collected {len(image_urls)} images so far')
    scroll_attempts += 1

# Convert low-res URLs to high-res
def get_high_res_url(src):
    resolutions = ['/originals/', '/564x/', '/736x/']
    for res in resolutions:
        high_res_url = src.replace('/60x60/', res).replace('/236x/', res)
        if requests.head(high_res_url).status_code == 200:
            return high_res_url
    return src  # Return original if higher resolution is not available

image_urls = list(map(get_high_res_url, image_urls))

# Download and save images
for img_url in image_urls:
    try:
        filename = os.path.basename(img_url).replace("/", "_")
        file_path = os.path.join(folder_name, filename)

        response = requests.get(img_url, stream=True)
        if response.status_code == 200:
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f"Saved: {file_path}")
        else:
            print(f"Failed to download: {img_url}")

    except Exception as e:
        print(f"Error saving {img_url}: {e}")

# Close the browser
driver.quit()
# Out:
# Scrolling... Collected 32 images so far
# Scrolling... Collected 45 images so far
# Scrolling... Collected 59 images so far
# Scrolling... Collected 71 images so far
# Scrolling... Collected 84 images so far
# Scrolling... Collected 97 images so far
# Scrolling... Collected 111 images so far
# Scrolling... Collected 123 images so far
# Scrolling... Collected 136 images so far
# Scrolling... Collected 148 images so far
# Scrolling... Collected 161 images so far
# Saved: tropical vacation/1c5ce48714547c51b452da747a3d9e44.jpg
# Saved: tropical vacation/d492e037267dfda7ef8ab4a53242f490.jpg
# Saved: tropical vacation/0e22b1bbfbb77c99c809518cf554070c.jpg
# Saved: tropical vacation/7510a4afdee4ccb95f308d25278bfe47.jpg
# Saved: tropical vacation/a05d24a5c4bbf611ba546bcc1fbf4645.jpg
# Saved: tropical vacation/3aa6ed25bda7e8a60a49b67571c84f81.jpg
# Saved: tropical vacation/db66df878d92d9eb3297021533834fa1.jpg
# Saved: tropical vacation/df863a138d37dbc266510cc192e6b02e.jpg
# Saved: tropical vacation/21225b103a10a9439c199f79aec03a2c.jpg
# Saved: tropical vacation/b5b7e5f6367eda8cb30665d63ab35bfb.jpg
# Saved: tropical vacation/4275af0f5d9dddd4356c3d299ae1b9fa.jpg
# Saved: tropical vacation/5e2ce07b01e6108edd72cbe955445530.jpg
# Saved: tropical vacation/10f487b3ad2a479f82adeefd6a562adb.jpg
# Saved: tropical vacation/7c1e6c87e15a38faec7f2c759249ef7b.jpg
# Saved: tropical vacation/128119f54d5acac221ede9128f3ba7b5.jpg
# Saved: tropical vacation/c4224859adf476f76c94b8cd3626d1fa.jpg
# Saved: tropical vacation/ede6d8bf27cd2e98e5862bfd1e7edded.jpg
# Saved: tropical vacation/785e01276282b5d2428ec97c3bf75ff1.jpg
# Saved: tropical vacation/480c551af4ea0d7e88c365b4f93d9b09.jpg
# Saved: tropical vacation/382ae8b6418db82fba6a7e5bdc079a00.jpg
# Saved: tropical vacation/57cc18e5b390760748e9fb684a8f1b55.jpg
# Saved: tropical vacation/6c2b7bd84716b34c6c043941094319a4.jpg
# Saved: tropical vacation/5ff20a267ba7b1d9ed2e8235bdd32008.jpg
# Saved: tropical vacation/95c7d95c087047886a9f51be258f6a88.jpg
# Saved: tropical vacation/7c0b4ae58ee0e9efdbff43875eeaeacc.jpg
# Saved: tropical vacation/9278076179422e8043159c2836be5a98.jpg
# Saved: tropical vacation/09f8bbb9cdb8e5ba788a223a14d8e8c5.jpg
# Saved: tropical vacation/faf4b501fb4aff445772cc1709add58e.jpg
# Saved: tropical vacation/50ed4d4eb339ca9e6ce1237744a469c6.jpg
# Saved: tropical vacation/2f676830ab3e6555deb3c51f124cb829.jpg
# Saved: tropical vacation/51e094431c287c6581c502993113c2d6.jpg
# Saved: tropical vacation/46cfec9b7940922cdda0b4b1f995a3d4.jpg
# Saved: tropical vacation/546258a93db9f3d52e9ca7b48ee83588.jpg
# Saved: tropical vacation/fc53ebd97a3a8b7dfa3781bd501f7035.jpg
# Saved: tropical vacation/0a56edd6a98d05ce83d0c6fa947f0044.jpg
# Saved: tropical vacation/068c1da9670882d5ce3c78b835acdd6a.jpg
# Saved: tropical vacation/a8c88eb01fd77b4ece7f4bfe1053165b.jpg
# Saved: tropical vacation/dbb56656e2500187b9c137c6a7a56bc9.jpg
# Saved: tropical vacation/1a8578b9b1926314a00b81ae834516a7.jpg
# Saved: tropical vacation/420140b45f06824b7cc260f223379c20.jpg
# Saved: tropical vacation/5307ffa8503787c7a66d925bc0ff78da.jpg
# Saved: tropical vacation/487fbbcf7bf93267c60ba7b19e6dfae6.jpg
# Saved: tropical vacation/479bcb48bfa351ef647d26e3bba7b7c2.jpg
# Saved: tropical vacation/0eb9a2e4535041b2d3fb4a77d12212b9.jpg
# Saved: tropical vacation/93bb7c17d5f19ac3a4b0062269fe9368.jpg
# Saved: tropical vacation/46688cc4fc44cd6f8f2cfa04b8cf77f3.jpg
# Saved: tropical vacation/103171d20c14b5be545a53dcfc4f1940.jpg
# Saved: tropical vacation/e60814fcf83c63aeaa33baac033cd946.jpg
# Saved: tropical vacation/d922f0211b5ce0875163a817fdeac683.jpg
# Saved: tropical vacation/b0cf74085ab0abd7ee60b64711f76c07.jpg
# Saved: tropical vacation/04bfc040ba34379cc896f70500c34a18.jpg
# Saved: tropical vacation/b26ab5f2867c7bb4924e6bd8682b613d.jpg
# Saved: tropical vacation/0d21375e66988516a97b7cdc7a2c8b81.jpg
# Saved: tropical vacation/1c2cdda43863744f4b370f5cb8a20c16.jpg
# Saved: tropical vacation/bc5386c645bab2db17ea10ad933c6156.jpg
# Saved: tropical vacation/12f72d6d7930da2aad6e729b780e5d20.jpg
# Saved: tropical vacation/4b6d61ebad2593373decc672d388eb32.jpg
# Saved: tropical vacation/df1dfaf7b3bfff0313605e74d746476c.jpg
# Saved: tropical vacation/3f735d2103460a14877a843df184e1e3.jpg
# Saved: tropical vacation/a2b8ec76e966d79587ea44ed5dbb085c.jpg
# Saved: tropical vacation/f029fc956839a8a05919a0cc9231bd09.jpg
# Saved: tropical vacation/65f0b7133a3439ce52083b31cda250b2.jpg
# Saved: tropical vacation/2b276f326c2c05f5e06cd20bbcd95ea0.jpg
# Saved: tropical vacation/4f6ce6de99cf8c5f1bdbb21dfa0a7932.jpg
# Saved: tropical vacation/77d4ce1a8c30c54fb21372001fddab1f.jpg
# Saved: tropical vacation/02da6586e6efde0c851193f3fc909468.jpg
# Saved: tropical vacation/354b4116f6d3f592987050c6bafcaa16.jpg
# Saved: tropical vacation/695f4e3f888af46b0e3028b77b8c1897.jpg
# Saved: tropical vacation/1ba92dcec99618a6262c27470b7239eb.jpg
# Saved: tropical vacation/cd19f51c74f7d6198824d5a5a9b2018b.jpg
# Saved: tropical vacation/3da03c332dae60ae51e6004d87caccce.jpg
# Saved: tropical vacation/7ff1cf938ad89c57885a5f695d9b3465.jpg
# Saved: tropical vacation/920410f93dfeebf13f64fd47d25634f8.jpg
# Saved: tropical vacation/ef03579020db783a201df070a65ac11a.jpg
# Saved: tropical vacation/f46ed4eaca5d57f7a34b0250f64cdd8d.jpg
# Saved: tropical vacation/b12609bff2282490057c45a3cded7a33.jpg
# Saved: tropical vacation/0a64b7466f28f6b88fa35a6793f9185d.jpg
# Saved: tropical vacation/cc684f94b648c622e9698ebe0345ad64.jpg
# Saved: tropical vacation/c8811de29957135e1d91b17c4a2b9bf7.jpg
# Saved: tropical vacation/f9cfbf603a036aba48e64856c7347e4e.jpg
# Saved: tropical vacation/c56f614a3f5fcdd2800d2cdd1b82aa3e.jpg
# Saved: tropical vacation/02fb321bfbf90a1c48f08859875cedca.jpg
# Saved: tropical vacation/11b9841f5b3300660dbb88a5db1cb085.jpg
# Saved: tropical vacation/611431f38eb06fbede0bf86f343ee051.jpg
# Saved: tropical vacation/0462b657d856400c02980f885f3e4de5.jpg
# Saved: tropical vacation/0e984a970fc7a877d30e4ab036afe1e5.jpg
# Saved: tropical vacation/959aceabebd56f5d20f85b27402b554a.jpg
# Saved: tropical vacation/6cd51c81cc301cd3dee6a708674c0b75.jpg
# Saved: tropical vacation/da94256601fd6fde47cb45700fd62833.jpg
# Saved: tropical vacation/7664a7dda567dac1a5f5c63f01dda642.jpg
# Saved: tropical vacation/15b9a50dc7ef7db702a28ed7e26be752.jpg
# Saved: tropical vacation/2e63b0db2e622d30fc6e71fac178854c.jpg
# Saved: tropical vacation/96f543fee03addd0e90062cecdbecb91.jpg
# Saved: tropical vacation/8a2263a1a5d813d205ef18a5e9c6b9ac.jpg
# Saved: tropical vacation/316893a9ce4efd4fd04a727e9b659ea0.jpg
# Saved: tropical vacation/54dbce7c52a9fa83d47a5d6e54fddff8.jpg
# Saved: tropical vacation/8dc921147254a5b1e3f05b2dd0600fdf.jpg
# Saved: tropical vacation/7912cfabc21b1a1a2d87cf57023783b8.jpg
# Saved: tropical vacation/8e4ed28060a4afb99566d40c9025a8f3.jpg
# Saved: tropical vacation/68fcc6f73ff51ec30707499c04070f50.jpg
# Saved: tropical vacation/695d67dbf714eecc348761cf386ffe6c.jpg
# Saved: tropical vacation/423554d896f7cc5ec7e64d70c1be92ed.jpg
# Saved: tropical vacation/7deffdb5e4ca74e618414baf8a2842ba.jpg
# Saved: tropical vacation/78b2ea5756ff24d795d2e54d99d74c92.jpg
# Saved: tropical vacation/f42c3d50c8bc0c126356cf1bc7938b77.jpg
# Saved: tropical vacation/052bded615cc1efc3e089517552c7334.jpg
# Saved: tropical vacation/e7059664024befe30935f40138254a59.jpg
# Saved: tropical vacation/965053de8f519a520990b2a04b2dcdf1.jpg
# Saved: tropical vacation/fefa45e4997a7b27109b0b03b6128022.jpg
# Saved: tropical vacation/3fbd8c251e589d8ede24971eb0753377.jpg
# Saved: tropical vacation/ff7c728d09025fef5ae4f1accc352f72.jpg
# Saved: tropical vacation/d74a289edc46bd8300d463a5894a5fc4.jpg
# Saved: tropical vacation/2fab99d2e21b387cd5b5a9a37b29d391.jpg
# Saved: tropical vacation/ff0da2d5a121576f7f09f67c0a0dd94c.jpg
# Saved: tropical vacation/e73a7157b4ddbafcf73a9986f2b78121.jpg
# Saved: tropical vacation/77290b8f3c9baa425b2569f30db67149.jpg
# Saved: tropical vacation/48519456c25316604007be08ca5faf4a.jpg
# Saved: tropical vacation/7bbcd2e64dfcce1524f6907855f7914d.jpg
# Saved: tropical vacation/334cdb883e7498c2969d8c0ba3fd96af.jpg
# Saved: tropical vacation/f1d7b74a45a53a108fb300620cc4c4ae.jpg
# Saved: tropical vacation/4f24a5f8145b43393c38469056f88f2f.jpg
# Saved: tropical vacation/52e9d8f17235eed9b19672228d2ac95f.jpg
# Saved: tropical vacation/3aac22e2c538901ff7fa5152e9dcecef.jpg
# Saved: tropical vacation/6cfc98e4b8e9e9212f339b9aca6035b6.jpg
# Saved: tropical vacation/9acb92f14ff79f9175ba2d4fc225603a.jpg
# Saved: tropical vacation/1782b14baae43bd71b8422ab8bc2d3f5.jpg
# Saved: tropical vacation/9379f669f4ab1464a74b439351d2ccf6.jpg
# Saved: tropical vacation/529f5d434e6397183260ed2ea15986f2.jpg
# Saved: tropical vacation/d37e45dc5f8f93e4e183eaf7db9c3d0d.jpg
# Saved: tropical vacation/c1fe2223efa3aeb486a30f671e8a672a.jpg
# Saved: tropical vacation/71e6ce095f28a54267987afe6734f746.jpg
# Saved: tropical vacation/d10bcf94f5e8b161a3e2fee4807c21ea.jpg
# Saved: tropical vacation/58636d524ed7a20e49179920b5047c5f.jpg
# Saved: tropical vacation/312d8d88977a72affd0fb4d822d7932b.jpg
# Saved: tropical vacation/9ce9ee945317c7da8a1b13913d445e58.jpg
# Saved: tropical vacation/679fb27b0084f6033e098bea91949807.jpg
# Saved: tropical vacation/80fe9880153657c03a824341bc8e3d5c.jpg
# Saved: tropical vacation/a1e7e8aa52ce4a191991cf5546e5ac75.jpg
# Saved: tropical vacation/518de031e8a3ba3608476b12f2d1209b.jpg
# Saved: tropical vacation/b6481e31316476657ac84b8c6766205c.jpg
# Saved: tropical vacation/dc141b760f6906ac172cd9ff0a377e76.jpg
# Saved: tropical vacation/47bc8a55d4475b0f8e31e7f9f2fe4e30.jpg
# Saved: tropical vacation/bce0b3d5987983ef5ab991dca7fd7beb.jpg
# Saved: tropical vacation/796ae6d0ba0a03c6781661c850642457.jpg
# Saved: tropical vacation/e6247f0d1b69389c771830324eb8b175.jpg
# Saved: tropical vacation/945e5c757d2b6126bb37d7a16c6f2c55.jpg
# Saved: tropical vacation/678dfca1c80a3b88f106551c211dff04.jpg
# Saved: tropical vacation/3841e47d5d36a7105e88d61b0162a2b6.jpg
# Saved: tropical vacation/1c413f995e3682df0ba1511765edcd3e.jpg
# Saved: tropical vacation/8de216c7b1f5fe37e7c7a7e04ea63949.jpg
# Saved: tropical vacation/dc66eb396f1c74bcbf5454121c88e06b.jpg
# Saved: tropical vacation/a09085ef92287fe955b4d07d7f67892b.jpg
# Saved: tropical vacation/f3f70374b296f1cc8631e52c39ab6088.jpg
# Saved: tropical vacation/8eb938ce1e89d2217daa3bb6f5d7005f.jpg
# Saved: tropical vacation/316893a9ce4efd4fd04a727e9b659ea0.jpg
# Saved: tropical vacation/d39c8eb0061e019e4800936044db4142.jpg
# Saved: tropical vacation/871ee8c43504cc62a45b35df4490e8b5.jpg
# Saved: tropical vacation/e6cba176388ad0eacb62089cc9386893.jpg
# Saved: tropical vacation/ed719b229a033df67ec39d249b2d09ff.jpg
# Saved: tropical vacation/74afa60d99a001bf14faa1e1c9ab2f4b.jpg
# Saved: tropical vacation/6f40b04c2b2f9206ed0ad941c30830b8.jpg
