# %%
import pandas as pd

# %%
df = pd.read_csv('refreshed.csv')

# %%
df
# Out:
#         shortcode                                     head_image_url  \
# 0     DBqaqZFye1P  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 1     DIfxeTESmAH  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 2     DAghuC8O3K1  https://scontent-lax3-2.cdninstagram.com/v/t39...
# 3     DDO76ScyKdo  https://scontent-lax3-1.cdninstagram.com/v/t51...
# 4     DEnFjlmsa59  https://scontent-lax3-2.cdninstagram.com/v/t51...
# ...           ...                                                ...
# 1220  DIWPEtARDLr  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 1221  DDzukH8yY_N  https://scontent-lax3-1.cdninstagram.com/v/t51...
# 1222  DFwDbkQtLkj  https://scontent-lax3-1.cdninstagram.com/v/t51...
# 1223  DA0vlNTpDR9  https://scontent-lax3-1.cdninstagram.com/v/t51...
# 1224  DBiX177RrGn  https://scontent-lax3-2.cdninstagram.com/v/t51...
#
#                                             music_title  \
# 0                                        chocolate milk
# 1                                           Superpowers
# 2                       Don’t Walk Away...Just Trust Me
# 3                                                 s2wik
# 4                                           Dear Winter
# ...                                                 ...
# 1220                                         Nobody New
# 1221                                             luther
# 1222                                     Venus as a Boy
# 1223                                        Agora Hills
# 1224  Beauty and the Beast (from "Beauty and the Bea...
#
#                       music_artist
# 0                            yawn.
# 1                        Muni Long
# 2                       Tory Lanez
# 3                            Aminé
# 4           Larry June, Jay Worthy
# ...                            ...
# 1220                    The Marías
# 1221           Kendrick Lamar, SZA
# 1222                         Bjork
# 1223                      Doja Cat
# 1224  Magic Philharmonic Orchestra
#
# [1225 rows x 4 columns]

# %%
# df[0:1]['link'].values[0] 

#download the link (its an image), and name it with the value of the first column: df[0:1]['shortcode'].values[0]  ."extension"

# df[0:1]['link'].values[0]
# df[0:1]['shortcode'].values[0]
# df[0:1]['link'].values[0].split('.')[-1]

def download_image(idx,url, name):
    import requests
    from pathlib import Path

    # Create a directory to save the images if it doesn't exist
    # Path('images').mkdir(parents=True, exist_ok=True)
    if not Path('images').exists():
        Path('images').mkdir(parents=True, exist_ok=True)

    # If the name already exists, skip downloading
    if Path(f'images/{name}').exists():
        print(f"({idx}) {name} already exists, skipping download.")
        return

    # Download the image
    response = requests.get(url)
    if response.status_code == 200:
        with open(f'images/{name}', 'wb') as f:
            f.write(response.content)
        print(f"({idx}) Downloaded {name}")
    else:
        print(f"({idx}) Failed to download {url}")
        
        
# for i in range(len(df)):
for idx, i in enumerate(df.index):
    # Get the URL and name for each image
    url = df[i:i+1]['head_image_url'].values[0]
    name = f"{df[i:i+1]['shortcode'].values[0]}.jpg"
    
    # Download the image
    download_image(idx,url, name)
# Out:
# DBqaqZFye1P.jpg already exists, skipping download.
# DIfxeTESmAH.jpg already exists, skipping download.
# DAghuC8O3K1.jpg already exists, skipping download.
# DDO76ScyKdo.jpg already exists, skipping download.
# DEnFjlmsa59.jpg already exists, skipping download.
# DDZ-kx_o54j.jpg already exists, skipping download.
# C1z5LUcv9NW.jpg already exists, skipping download.
# DC-DXv2xR6T.jpg already exists, skipping download.
# DGLjZsMP6Lv.jpg already exists, skipping download.
# C7J-2gTrsWo.jpg already exists, skipping download.
# DFPhbz-yHOw.jpg already exists, skipping download.
# C7E2fypuXDE.jpg already exists, skipping download.
# DIeR4VPM8aB.jpg already exists, skipping download.
# DHRC3ioR9dW.jpg already exists, skipping download.
# DGOFeonqTrK.jpg already exists, skipping download.
# DCE6U_DRCLc.jpg already exists, skipping download.
# DD69osFSXCR.jpg already exists, skipping download.
# C8kSOBHPleZ.jpg already exists, skipping download.
# DF0FhGeym9Z.jpg already exists, skipping download.
# DAgUVg_TFDp.jpg already exists, skipping download.
# DBoqp-ByDMg.jpg already exists, skipping download.
# DH_AVl6J4-3.jpg already exists, skipping download.
# DHaxuCqpD65.jpg already exists, skipping download.
# DEVEJNFMwI8.jpg already exists, skipping download.
# C-0Q8c_ypV7.jpg already exists, skipping download.
# DAMuGsVy7JX.jpg already exists, skipping download.
# C2AgBmQsmnF.jpg already exists, skipping download.
# C-slIxIRRnG.jpg already exists, skipping download.
# DCw1yKqRjTP.jpg already exists, skipping download.
# DFAuwduSY-S.jpg already exists, skipping download.
# DGtBxDdzPob.jpg already exists, skipping download.
# DCHam0ryLtC.jpg already exists, skipping download.
# C_9d6MwSV-_.jpg already exists, skipping download.
# DIHQbvcPuN9.jpg already exists, skipping download.
# C_H_Wtmy_32.jpg already exists, skipping download.
# DAG1e6GyAXI.jpg already exists, skipping download.
# C94IoMNyR8E.jpg already exists, skipping download.
# C9d0Cjkyed0.jpg already exists, skipping download.
# DCMnJbNRwZi.jpg already exists, skipping download.
# Downloaded C8ScD4hunBK.jpg
# Downloaded DB0OqHxzUUK.jpg
# Downloaded DHf2useSd2m.jpg
# Downloaded DBT2XQWP7ga.jpg
# Downloaded C_GO_DdJzFd.jpg
# Downloaded DEDJcuexss1.jpg
# Downloaded C0w8T5RvBI-.jpg
# Downloaded DEhOfMoTJsD.jpg
# Downloaded C9KecneS54X.jpg
# Downloaded DBTn8x3zGtD.jpg
# Downloaded C6T-CM6Rqg9.jpg
# Downloaded DHEX_MpqMxK.jpg
# Downloaded C_kbSMxzTCs.jpg
# Downloaded DHdTNv_pmJN.jpg
# Downloaded DB1iHj_RmpT.jpg
# Downloaded DIip2tlyfAB.jpg
# Downloaded C_e-Za6TwRQ.jpg
# Downloaded C1sZCxFyLyj.jpg
# Downloaded DGiy6iux_yj.jpg
# Downloaded C9w94JlhFOs.jpg
# Downloaded DAROFdgRFgR.jpg
# Downloaded C_3WSrEMxyh.jpg
# Downloaded DD_4Gk9T5oY.jpg
# Downloaded DFwGVyjO0xu.jpg
# Downloaded DFxFBQMzJnw.jpg
# Downloaded DFhVFxQpG7D.jpg
# Downloaded DEAG50nSWiP.jpg
# Downloaded C7gamGbu6SD.jpg
# Downloaded DCmAOrIPH0E.jpg
# Downloaded DIWxY5oSpVa.jpg
# Downloaded C8eomEdhH7t.jpg
# Downloaded DGzO5tQTKPo.jpg
# Downloaded DH3yC55vLWA.jpg
# Downloaded DGh30imq1O_.jpg
# Downloaded DAarFbRTfRI.jpg
# Downloaded DFOaI0duLkl.jpg
# Downloaded DDFrY_SyfyW.jpg
# Downloaded DH3imzyzzvw.jpg
# Downloaded C72nnTYO_0V.jpg
# Downloaded DAjDPp1uL6v.jpg
# Downloaded DCeHx5eTDhr.jpg
# Downloaded DGrGNqMpdrB.jpg
# Downloaded DAvBbJOpA26.jpg
# Downloaded DHV3KuuuOAW.jpg
# Downloaded DA3AwjEzHYS.jpg
# Downloaded C_i3io0RzAR.jpg
# Downloaded C6rlETZSqUC.jpg
# Downloaded DD-OXVdyzNF.jpg
# Downloaded DDg648yTIuZ.jpg
# Downloaded DCERuDgyneQ.jpg
# Downloaded DESZdCPyqL6.jpg
# Downloaded C-X_AkKuEz0.jpg
# Downloaded C3gBuWRgMXh.jpg
# Downloaded DCoHEDMzWd9.jpg
# Downloaded C7Eyxv-O3pv.jpg
# Downloaded DE8VY7psXrg.jpg
# Downloaded DHspOvcTXuS.jpg
# Downloaded DHvns66TTfk.jpg
# Downloaded DH6OZD8AskO.jpg
# Downloaded DFbM62lyLgs.jpg
# Downloaded DIdK_DDJrnT.jpg
# Downloaded C_-Kq86Sf4k.jpg
# Downloaded C_UfHZ-TGtC.jpg
# Downloaded DIMcsIsOls0.jpg
# Downloaded C-vDiCrRi7M.jpg
# Downloaded DEwqw6op65g.jpg
# Downloaded C8_85ayKQbK.jpg
# Downloaded DIdy9-MzPfq.jpg
# Downloaded C5sTL6nLDZs.jpg
# Downloaded DB8kYBOTzQC.jpg
# Downloaded C_h5dhhSkXG.jpg
# Downloaded DCcG3REumMz.jpg
# Downloaded DE9qfyBT5Gw.jpg
# Downloaded C_2do4kyyS3.jpg
# Downloaded CzybwmqhZ-U.jpg
# Downloaded DIHGWaWuAKN.jpg
# Downloaded DIiudAdR9cK.jpg
# Downloaded DB1guBvRGM4.jpg
# Downloaded C_XRO7TuP-B.jpg
# Downloaded DG3WS3mNGBU.jpg
# Downloaded DHPw1iyz3Ve.jpg
# Downloaded DEQdgxnyGmB.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 39
#      36 name = f"{df[i:i+1]['shortcode'].values[0]}.jpg"
#      38 # Download the image
# ---> 39 download_image(url, name)
#
# Cell In[6], line 24, in download_image(url, name)
#      21     return
#      23 # Download the image
# ---> 24 response = requests.get(url)
#      25 if response.status_code == 200:
#      26     with open(f'images/{name}', 'wb') as f:
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/urllib3/response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066         data = self.read(amt=amt, decode_content=decode_content)
#    1068         if data:
#    1069             yield data
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/urllib3/response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/urllib3/response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)    887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/site-packages/urllib3/response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/basic-venv/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
