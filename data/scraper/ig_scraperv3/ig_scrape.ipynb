# %%
pip install httpx
# Out:
# Collecting httpx
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx)
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi (from httpx)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx)
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting sniffio>=1.1 (from anyio->httpx)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, idna, h11, certifi, httpcore, anyio, httpx
# Successfully installed anyio-4.9.0 certifi-2025.1.31 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import httpx
import json
from typing import Dict
from urllib.parse import quote

# %%
def scrape_post(ig_doc_id ,url_or_shortcode: str) -> Dict:
    """Scrape single Instagram post data"""
    print(f"Scraping: {url_or_shortcode}, id: {ig_doc_id}")
    
    if "http" in url_or_shortcode:
        shortcode = url_or_shortcode.split("/p/")[-1].split("/")[0]
    else:
        shortcode = url_or_shortcode

    variables = quote(json.dumps({
        'shortcode':shortcode,'fetch_tagged_user_count':None,
        'hoisted_comment_id':None,'hoisted_reply_id':None
    }, separators=(',', ':')))
    body = f"variables={variables}&doc_id={ig_doc_id}"
    url = "https://www.instagram.com/graphql/query"

    result = httpx.post(
        url=url,
        headers={"content-type": "application/x-www-form-urlencoded"},
        data=body
    )
    data = json.loads(result.content)
    
    print(data)
    
    # return data["data"]["xdt_shortcode_media"]
    return data

# %%
# document id for content query:
#more post content: 
# IG_DOC_ID = "9195084877213487"
#more content
# IG_DOC_ID = "9507655305965624"



#relationships/related : 9480525715305126
# IG_DOC_ID = "9480525715305126"
#acc metadata: 9109150515847101
# IG_DOC_ID = "9109150515847101"
#reels: 9318096484942317
# IG_DOC_ID = "9318096484942317"

# %%
 ! pip install pytest-playwright
 ! playwright install
# Out:
# Collecting pytest-playwright
#   Downloading pytest_playwright-0.7.0-py3-none-any.whl.metadata (14 kB)
# Collecting playwright>=1.18 (from pytest-playwright)
#   Downloading playwright-1.51.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting pytest<9.0.0,>=6.2.4 (from pytest-playwright)
#   Downloading pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-base-url<3.0.0,>=1.0.0 (from pytest-playwright)
#   Downloading pytest_base_url-2.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting python-slugify<9.0.0,>=6.0.0 (from pytest-playwright)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting pyee<13,>=12 (from playwright>=1.18->pytest-playwright)
#   Using cached pyee-12.1.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting greenlet<4.0.0,>=3.1.1 (from playwright>=1.18->pytest-playwright)
#   Downloading greenlet-3.1.1-cp313-cp313-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting iniconfig (from pytest<9.0.0,>=6.2.4->pytest-playwright)
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: packaging in /Users/chaewonbang/your-story/ig-project/.venv/lib/python3.13/site-packages (from pytest<9.0.0,>=6.2.4->pytest-playwright) (24.2)
# Collecting pluggy<2,>=1.5 (from pytest<9.0.0,>=6.2.4->pytest-playwright)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting requests>=2.9 (from pytest-base-url<3.0.0,>=1.0.0->pytest-playwright)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting text-unidecode>=1.3 (from python-slugify<9.0.0,>=6.0.0->pytest-playwright)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting typing-extensions (from pyee<13,>=12->playwright>=1.18->pytest-playwright)
#   Downloading typing_extensions-4.13.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright)
#   Downloading charset_normalizer-3.4.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chaewonbang/your-story/ig-project/.venv/lib/python3.13/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chaewonbang/your-story/ig-project/.venv/lib/python3.13/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2025.1.31)
# Downloading pytest_playwright-0.7.0-py3-none-any.whl (16 kB)
# Downloading playwright-1.51.0-py3-none-macosx_11_0_arm64.whl (38.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 7.5 MB/s eta 0:00:00a 0:00:01m
# Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
# Downloading pytest_base_url-2.1.0-py3-none-any.whl (5.3 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading greenlet-3.1.1-cp313-cp313-macosx_11_0_universal2.whl (272 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached pyee-12.1.1-py3-none-any.whl (15 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Downloading charset_normalizer-3.4.1-cp313-cp313-macosx_10_13_universal2.whl (195 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading typing_extensions-4.13.1-py3-none-any.whl (45 kB)
# Installing collected packages: text-unidecode, urllib3, typing-extensions, python-slugify, pluggy, iniconfig, greenlet, charset-normalizer, requests, pytest, pyee, pytest-base-url, playwright, pytest-playwright
# Successfully installed charset-normalizer-3.4.1 greenlet-3.1.1 iniconfig-2.1.0 playwright-1.51.0 pluggy-1.5.0 pyee-12.1.1 pytest-8.3.5 pytest-base-url-2.1.0 pytest-playwright-0.7.0 python-slugify-8.0.4 requests-2.32.3 text-unidecode-1.3 typing-extensions-4.13.1 urllib3-2.3.0
# Removing unused browser at /Users/chaewonbang/Library/Caches/ms-playwright/chromium_headless_shell-1155
# Downloading Chromium 134.0.6998.35 (playwright build v1161) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1161/chromium-mac-arm64.zip
# 124.1 MiB [                    ] 0% 0.0s124.1 MiB [                    ] 0% 13.8s124.1 MiB [                    ] 0% 11.4s124.1 MiB [                    ] 0% 9.3s124.1 MiB [                    ] 0% 14.3s124.1 MiB [                    ] 0% 14.5s124.1 MiB [                    ] 0% 12.2s124.1 MiB [                    ] 1% 12.6s124.1 MiB [                    ] 1% 12.8s124.1 MiB [                    ] 1% 14.5s124.1 MiB [                    ] 1% 12.7s124.1 MiB [                    ] 1% 12.8s124.1 MiB [                    ] 2% 14.3s124.1 MiB [                    ] 2% 13.2s124.1 MiB [                    ] 2% 19.6s124.1 MiB [=                   ] 2% 19.8s124.1 MiB [=                   ] 2% 18.3s124.1 MiB [=                   ] 3% 17.5s124.1 MiB [=                   ] 3% 16.3s124.1 MiB [=                   ] 3% 15.7s124.1 MiB [=                   ] 3% 14.9s124.1 MiB [=                   ] 4% 14.2s124.1 MiB [=                   ] 4% 13.5s124.1 MiB [=                   ] 4% 13.0s124.1 MiB [=                   ] 4% 12.7s124.1 MiB [=                   ] 5% 13.1s124.1 MiB [=                   ] 5% 12.8s124.1 MiB [=                   ] 5% 12.3s124.1 MiB [=                   ] 5% 12.4s124.1 MiB [=                   ] 6% 12.1s124.1 MiB [=                   ] 6% 11.9s124.1 MiB [=                   ] 6% 11.8s124.1 MiB [=                   ] 6% 11.5s124.1 MiB [=                   ] 7% 11.3s124.1 MiB [=                   ] 7% 11.1s124.1 MiB [==                  ] 7% 10.9s124.1 MiB [==                  ] 7% 10.7s124.1 MiB [==                  ] 7% 11.7s124.1 MiB [==                  ] 8% 11.4s124.1 MiB [==                  ] 8% 11.2s124.1 MiB [==                  ] 8% 11.0s124.1 MiB [==                  ] 9% 10.8s124.1 MiB [==                  ] 9% 10.5s124.1 MiB [==                  ] 9% 10.3s124.1 MiB [==                  ] 10% 10.1s124.1 MiB [==                  ] 10% 10.0s124.1 MiB [==                  
] 20% 3.6s65.7 MiB [====                ] 21% 3.6s65.7 MiB [====                ] 22% 3.5s65.7 MiB [=====               ] 22% 3.4s65.7 MiB [=====               ] 23% 3.4s65.7 MiB [=====               ] 24% 3.3s65.7 MiB [=====               ] 24% 3.2s65.7 MiB [=====               ] 25% 3.2s65.7 MiB [=====               ] 25% 3.1s65.7 MiB [=====               ] 26% 3.1s65.7 MiB [=====               ] 27% 3.0s65.7 MiB [======              ] 27% 3.2s65.7 MiB [======              ] 28% 3.1s65.7 MiB [======              ] 29% 3.0s65.7 MiB [======              ] 30% 3.0s65.7 MiB [======              ] 30% 2.9s65.7 MiB [======              ] 31% 2.8s65.7 MiB [======              ] 32% 3.0s65.7 MiB [=======             ] 33% 2.9s65.7 MiB [=======             ] 34% 2.8s65.7 MiB [=======             ] 35% 2.8s65.7 MiB [=======             ] 35% 2.7s65.7 MiB [=======             ] 36% 2.7s65.7 MiB [========            ] 37% 2.6s65.7 MiB [========            ] 38% 2.5s65.7 MiB [========            ] 39% 2.5s65.7 MiB [========            ] 40% 2.4s65.7 MiB [========            ] 41% 2.4s65.7 MiB [========            ] 41% 2.5s65.7 MiB [========            ] 42% 2.5s65.7 MiB [=========           ] 42% 2.4s65.7 MiB [=========           ] 43% 2.4s65.7 MiB [=========           ] 43% 2.3s65.7 MiB [=========           ] 44% 2.3s65.7 MiB [=========           ] 44% 2.4s65.7 MiB [=========           ] 45% 2.4s65.7 MiB [=========           ] 46% 2.3s65.7 MiB [==========          ] 47% 2.2s65.7 MiB [==========          ] 48% 2.2s65.7 MiB [==========          ] 49% 2.1s65.7 MiB [==========          ] 50% 2.1s65.7 MiB [==========          ] 51% 2.0s65.7 MiB [==========          ] 52% 2.0s65.7 MiB [===========         ] 53% 1.9s65.7 MiB [===========         ] 53% 2.0s65.7 MiB [===========         ] 54% 1.9s65.7 MiB [===========         ] 55% 1.9s65.7 MiB [===========         ] 56% 1.8s65.7 MiB [===========         ] 57% 1.8s65.7 MiB [============        ] 57% 1.7s65.7 MiB [============        ] 58% 1.7s65.7 MiB [============        ] 59% 1.7s65.7 MiB [============        ] 60% 1.7s65.7 MiB [============        ] 61% 1.6s65.7 MiB [============        ] 62% 1.6s65.7 MiB [=============       ] 62% 1.5s65.7 MiB [=============       ] 63% 1.5s65.7 MiB [=============       ] 64% 1.5s65.7 MiB [=============       ] 64% 1.4s65.7 MiB [=============       ] 65% 1.4s65.7 MiB [=============       ] 66% 1.3s65.7 MiB [=============       ] 67% 1.3s65.7 MiB [==============      ] 67% 1.3s65.7 MiB [==============      ] 68% 1.2s65.7 MiB [==============      ] 68% 1.3s65.7 MiB [==============      ] 69% 1.2s65.7 MiB [======= ...
# Webkit 18.4 (playwright build v2140) downloaded to /Users/chaewonbang/Library/Caches/ms-playwright/webkit-2140

# %%
import asyncio
from playwright.async_api import async_playwright
import re
import json

# %%
#This is a dynamic environment that stays open after execution

# Global references for easy access across notebook cells
playwright = await async_playwright().start()
device = playwright.devices["Pixel 5"]
browser = await playwright.chromium.launch(headless=False)  # Browser will stay open
context = await browser.new_context(**device)
page = await context.new_page()
# You now have persistent global references:
# playwright, browser, context, page

# %%
! pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0

# %%
from dotenv import load_dotenv
#load the .env file
# get USERNAME and PASSWORD
load_dotenv(override=True)
import os
username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")

# %%
username
# Out:
# 'databot363792934'

# %%
#signon doesn't work rn

import asyncio
from playwright.async_api import TimeoutError

async def signon(page, username, password):
    try:
        await page.goto("https://www.instagram.com/accounts/login/", wait_until="networkidle")

        
        await page.wait_for_selector('input[name="username"]', timeout=10000)
        await asyncio.sleep(0.5)
        await page.fill('input[name="username"]', username)
        await asyncio.sleep(0.5)
        await page.fill('input[name="password"]', password)
        await asyncio.sleep(0.5)

        await page.click('button[type="submit"]')
        await asyncio.sleep(1)

        # Wait for navigation or check for login errors
        await page.wait_for_selector('nav', timeout=10000)  # Wait for main navigation bar as successful login indicator

        # Verify successful login by checking URL or user-specific elements
        if "login" in page.url:
            raise ValueError("Login failed: Incorrect username or password.")

        print("✅ Successfully logged in")
        
        return

    except TimeoutError:
        raise TimeoutError("Login timed out. Check credentials or network connection.")

# %%
#it says it fails but it works
await signon(page, username, password)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 #it says it fails but it works
# ----> 2 await signon(page, username, password)
#
# Cell In[63], line 26, in signon(page, username, password)
#      24 # Verify successful login by checking URL or user-specific elements
#      25 if "login" in page.url:
# ---> 26     raise ValueError("Login failed: Incorrect username or password.")
#      28 print("✅ Successfully logged in")
#      30 return
#
# ValueError: Login failed: Incorrect username or password.

# %%
from random import randint

# %%
import asyncio
import re
import json
from random import randint
from datetime import datetime

async def get_total_posts(page):
    """Extracts the total number of posts from the user's profile."""
    total_posts = await page.evaluate("""
        () => {
            let element = document.querySelector('header section ul li span');
            return element ? parseInt(element.innerText.replace(',', '')) : null;
        }
    """)
    return total_posts if total_posts else float('inf')

async def get_post_date(post_element):
    """Extracts the post date from a post element."""
    timestamp = await post_element.evaluate("""
        node => {
            let timeElem = node.querySelector('time');
            return timeElem ? timeElem.getAttribute('datetime') : null;
        }
    """)
    return datetime.fromisoformat(timestamp) if timestamp else None

MAX_SCROLLS = 10

async def scroll_to_load_all_posts(page, max_scrolls=MAX_SCROLLS):
    """Scrolls until a post from before January 2023 is found or max scroll limit is reached."""
    all_posts = set()
    previous_count = 0
    scroll_attempts = 0

    print(f"🔄 Starting scrolling process... (Max {max_scrolls} attempts)")
    
    while scroll_attempts < max_scrolls:
        posts = await page.query_selector_all("div._aagu")
        if not posts:
            print("⚠️ No posts found in current DOM snapshot.")
            break

        # Check last post's date to determine if we should stop scrolling
        last_post = posts[-1]
        last_post_date = await get_post_date(last_post)

        if last_post_date:
            print(f"🕒 Last post date: {last_post_date}")
            if last_post_date < datetime(2023, 1, 1):
                print(f"🛑 Found post from {last_post_date}, stopping scrolling.")
                break  # Stop scrolling if an old post is found

        for post in posts:
            parent = await post.evaluate_handle("node => node.closest('a')")
            if parent:
                href = await parent.get_attribute('href')
                if href and '/p/' in href:
                    if href not in all_posts:  # Only process new posts
                        post_date = await get_post_date(post)
                        if post_date:
                            print(f"📅 Found new post: {href} | Date: {post_date}")
                        all_posts.add(href)

        if len(all_posts) == previous_count:
            print(f"✅ Scrolling stopped after {scroll_attempts} attempts. Total unique posts found: {len(all_posts)}")
            break  # Stop if no new posts are loaded

        previous_count = len(all_posts)
        scroll_attempts += 1

        # Scroll and wait
        print(f"📜 Scrolling attempt {scroll_attempts}... (Loaded posts: {len(all_posts)})")
        await page.evaluate("window.scrollTo(0, document.body.scrollHeight);")
        await asyncio.sleep(3 + 0.1 * randint(0, 10))

    print(f"✅ Finished scrolling. Total posts loaded: {len(all_posts)}")
    return all_posts

# %%
import asyncio
import re
import json
from datetime import datetime

MAX_SCROLLS = 10
SCROLL_DELAY = 2  # Time between scrolls in seconds
testname = "daisychoiii"
profile_url = f"https://www.instagram.com/{testname}/"

### ========================= UTILITY FUNCTIONS ========================= ###
async def get_total_posts(page):
    """Extracts the total number of posts from the user's profile."""
    total_posts = await page.evaluate("""
        () => {
            let element = document.querySelector('header section ul li span');
            return element ? parseInt(element.innerText.replace(',', '')) : null;
        }
    """)
    return total_posts if total_posts else float('inf')

async def get_post_date(post_element):
    """Extracts the post date from a post element."""
    timestamp = await post_element.evaluate("""
        node => {
            let timeElem = node.querySelector('time');
            return timeElem ? timeElem.getAttribute('datetime') : null;
        }
    """)
    try:
        return datetime.fromisoformat(timestamp) if timestamp else None
    except Exception:
        return None

async def intercept_response(response, intercepted_posts, response_received_flag):
    """Intercepts post data from Instagram API responses."""
    endpoint_pattern = re.compile(r"/api/v1/media/\d+/info/")
    if endpoint_pattern.search(response.url) and response.status == 200:
        try:
            data = await response.json()
            media_id = data.get('items', [{}])[0].get('id', 'unknown')
            intercepted_posts[media_id] = data
            response_received_flag[0] = True
            print(f"✅ Intercepted post {media_id} ({len(intercepted_posts)} collected)")
        except Exception as e:
            print(f"❌ Failed to parse intercepted data: {e}")

### ========================= SCROLLING FUNCTION ========================= ###
async def scroll_to_load_all_posts(page, max_scrolls=MAX_SCROLLS):
    """Scrolls dynamically until the *last* visible post is from before January 2023 or max_scrolls is reached."""
    all_posts = set()
    previous_count = 0
    scroll_attempts = 0

    print(f"🔄 Starting scrolling process... (Max {max_scrolls} attempts)")

    while scroll_attempts < max_scrolls:
        posts = await page.query_selector_all("div._aagu")

        if not posts:
            print("⚠️ No posts found.")
            break

        # # Check the date of the last visible post only
        # last_post = posts[-1]
        # last_post_date = await get_post_date(last_post)

        # if last_post_date:
        #     print(f"🕒 Last post on page: {last_post_date}")
        #     if last_post_date < datetime(2023, 1, 1):
        #         print(f"🛑 Last post is before 2023. Stopping scroll.")
        #         break

        # Collect post links
        for post in posts:
            parent = await post.evaluate_handle("node => node.closest('a')")
            if parent:
                href = await parent.get_attribute('href')
                if href and '/p/' in href and href not in all_posts:
                    all_posts.add(href)

        if len(all_posts) == previous_count:
            print(f"✅ No new posts loaded after scroll {scroll_attempts}. Total: {len(all_posts)}")
            break

        previous_count = len(all_posts)
        scroll_attempts += 1

        print(f"📜 Scrolling attempt {scroll_attempts}... (Collected posts: {len(all_posts)})")
        await page.evaluate("window.scrollTo(0, document.body.scrollHeight);")
        await asyncio.sleep(SCROLL_DELAY)

    print(f"✅ Finished scrolling. Total posts collected: {len(all_posts)}")
    return all_posts

### ========================= NAVIGATION & DATA COLLECTION ========================= ###
async def navigate_and_collect(page, all_post_links):
    """Visits each post URL and collects data via API interception."""
    intercepted_posts = {}
    response_received_flag = [False]

    print(f"🟢 Total unique posts queued for processing: {len(all_post_links)}")

    # Register a single persistent response handler
    page.on("response", lambda response: asyncio.create_task(intercept_response(response, intercepted_posts, response_received_flag)))

    for i, href in enumerate(all_post_links, start=1):
        post_url = f"https://www.instagram.com{href}"
        print(f"\n({i}/{len(all_post_links)}) 📌 Navigating to: {post_url}")

        response_received_flag[0] = False  # Reset before each visit

        await page.goto(post_url, wait_until="networkidle")
        await asyncio.sleep(1)  # Allow responses to load

        # Wait dynamically for response interception (max 5 seconds)
        for _ in range(50):
            if response_received_flag[0]:
                break
            await asyncio.sleep(0.1)

        print("🔄 Returning to profile page...\n")
        await page.goto("about:blank")
        await page.goto(profile_url, wait_until="networkidle")
        await asyncio.sleep(1)

    print(f"\n🎉 **Scraping complete! Collected {len(intercepted_posts)} posts.**")
    return intercepted_posts

### ========================= MAIN SCRAPING FUNCTION ========================= ###
async def scrape_profile_posts(profile_url: str, page):
    """Orchestrates the entire scraping process."""
    print(f"🚀 Navigating to profile: {profile_url}")
    await page.goto(profile_url, wait_until="networkidle")
    await asyncio.sleep(1)

    total_posts = await get_total_posts(page)
    print(f"🔢 Total posts found on profile: {total_posts}")

    all_post_links = await scroll_to_load_all_posts(page)
    print(f"📸 Found {len(all_post_links)} unique posts after scrolling.")

    intercepted_posts = await navigate_and_collect(page, all_post_links)

    return intercepted_posts

### ========================= RUN SCRAPER ========================= ###
# Example usage:
data = await scrape_profile_posts(profile_url, page)
print(json.dumps(data, indent=2, default=str))
# Out:
# 🚀 Navigating to profile: https://www.instagram.com/daisychoiii/
# 🔢 Total posts found on profile: 114
# 🔄 Starting scrolling process... (Max 10 attempts)
# 📜 Scrolling attempt 1... (Collected posts: 19)
# 📜 Scrolling attempt 2... (Collected posts: 28)
# 📜 Scrolling attempt 3... (Collected posts: 40)
# 📜 Scrolling attempt 4... (Collected posts: 51)
# 📜 Scrolling attempt 5... (Collected posts: 62)
# ✅ No new posts loaded after scroll 5. Total: 62
# ✅ Finished scrolling. Total posts collected: 62
# 📸 Found 62 unique posts after scrolling.
# 🟢 Total unique posts queued for processing: 62
#
# (1/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DCn40cwRXlk/
# 🔄 Returning to profile page...
#
#
# (2/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CmDUTGSLQ6L/
# 🔄 Returning to profile page...
#
#
# (3/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cl2_DWGurV8/
# 🔄 Returning to profile page...
#
#
# (4/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CqUY-49Lgf4/
# 🔄 Returning to profile page...
#
#
# (5/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CwIE2h3r7AO/
# 🔄 Returning to profile page...
#
#
# (6/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CscKl1AyfgH/
# 🔄 Returning to profile page...
#
#
# (7/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DFzJ4LQxlTw/
# 🔄 Returning to profile page...
#
#
# (8/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C9yqOAGxIuB/
# 🔄 Returning to profile page...
#
#
# (9/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cr7LjfZr0B5/
# 🔄 Returning to profile page...
#
#
# (10/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C1TYCCHoGDw/
# 🔄 Returning to profile page...
#
#
# (11/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C4rHjEfLaXk/
# 🔄 Returning to profile page...
#
#
# (12/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CqzIo1FrVgt/
# 🔄 Returning to profile page...
#
#
# (13/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DADABUHR6EC/
# 🔄 Returning to profile page...
#
#
# (14/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CvSSaT4L9yX/
# 🔄 Returning to profile page...
#
#
# (15/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CnKOtXWJA64/
# 🔄 Returning to profile page...
#
#
# (16/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cm5H5_KIL6G/
# 🔄 Returning to profile page...
#
#
# (17/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DCgGK3TxJPY/
# 🔄 Returning to profile page...
#
#
# (18/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CwYe5DSypuq/
# 🔄 Returning to profile page...
#
#
# (19/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cod5Hdcrd6V/
# 🔄 Returning to profile page...
#
#
# (20/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DCYuI0YAzB_/
# 🔄 Returning to profile page...
#
#
# (21/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DC2lg1Bxl0l/
# 🔄 Returning to profile page...
#
#
# (22/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/ClhXUdYSYL1/
# 🔄 Returning to profile page...
#
#
# (23/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C7q_cXcxTY1/
# 🔄 Returning to profile page...
#
#
# (24/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CzFt5fRrXDb/
# 🔄 Returning to profile page...
#
#
# (25/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C8UzXc6ByUw/
# 🔄 Returning to profile page...
#
#
# (26/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CuicRWSpvYq/
# 🔄 Returning to profile page...
#
#
# (27/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Ct7BKDCJiKr/
# 🔄 Returning to profile page...
#
#
# (28/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CtXXezjSHFv/
# 🔄 Returning to profile page...
#
#
# (29/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CrFrClGODGu/
# 🔄 Returning to profile page...
#
#
# (30/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Clk7HNBu_Fn/
# 🔄 Returning to profile page...
#
#
# (31/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C9jU_gqx4cO/
# 🔄 Returning to profile page...
#
#
# (32/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C9ATcCThz0g/
# 🔄 Returning to profile page...
#
#
# (33/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cros99SPq_c/
# 🔄 Returning to profile page...
#
#
# (34/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cuff209ysr7/
# 🔄 Returning to profile page...
#
#
# (35/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C44wxyaA-CW/
# 🔄 Returning to profile page...
#
#
# (36/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cm-hfexIqmj/
# 🔄 Returning to profile page...
#
#
# (37/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DAfVk7Ex9MY/
# 🔄 Returning to profile page...
#
#
# (38/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DE34artRKWu/
# 🔄 Returning to profile page...
#
#
# (39/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C6C7vjWLp9H/
# 🔄 Returning to profile page...
#
#
# (40/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C8wjHPih5lt/
# 🔄 Returning to profile page...
#
#
# (41/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C9_1WhXx7Ai/
# 🔄 Returning to profile page...
#
#
# (42/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cy_06YZSvMg/
# 🔄 Returning to profile page...
#
#
# (43/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cpzb0mrOBdp/
# 🔄 Returning to profile page...
#
#
# (44/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CuGUg_cr0Hq/
# 🔄 Returning to profile page...
#
#
# (45/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cq3pY-iPhpT/
# 🔄 Returning to profile page...
#
#
# (46/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DGkOdP-R9fY/
# 🔄 Returning to profile page...
#
#
# (47/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DApb0t6xiq6/
# 🔄 Returning to profile page...
#
#
# (48/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C3ZNptULDfa/
# 🔄 Returning to profile page...
#
#
# (49/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CyKCoEWp7ME/
# 🔄 Returning to profile page...
#
#
# (50/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DA5XY-NxrOX/
# 🔄 Returning to profile page...
#
#
# (51/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C3rV1YQAaJe/
# 🔄 Returning to profile page...
#
#
# (52/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CmxLTk3rz_G/
# 🔄 Returning to profile page...
#
#
# (53/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C9rOP38APgi/
# 🔄 Returning to profile page...
#
#
# (54/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C71cdgBhi_V/
# 🔄 Returning to profile page...
#
#
# (55/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CyfcgEwuNkS/
# 🔄 Returning to profile page...
#
#
# (56/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Ck3d60prLA1/
# 🔄 Returning to profile page...
#
#
# (57/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/DCkm1ECyfpM/
# 🔄 Returning to profile page...
#
#
# (58/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C2blR8Crqmd/
# 🔄 Returning to profile page...
#
#
# (59/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/ClOwovGJEZS/
# 🔄 Returning to profile page...
#
#
# (60/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/C6FdNa2ract/
# 🔄 Returning to profile page...
#
#
# (61/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/Cxy0yVnvPKc/
# 🔄 Returning to profile page...
#
#
# (62/62) 📌 Navigating to: https://www.instagram.com/daisychoiii/p/CrEJJwrLto2/
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[73], line 149
#     145     return intercepted_posts
#     147 ### ========================= RUN SCRAPER ========================= ###
#     148 # Example usage:
# --> 149 data = await scrape_profile_posts(profile_url, page)
#     150 print(json.dumps(data, indent=2, default=str))
#
# Cell In[73], line 143, in scrape_profile_posts(profile_url, page)
#     140 all_post_links = await scroll_to_load_all_posts(page)
#     141 print(f"📸 Found {len(all_post_links)} unique posts after scrolling.")
# --> 143 intercepted_posts = await navigate_and_collect(page, all_post_links)
#     145 return intercepted_posts
#
# Cell In[73], line 113, in navigate_and_collect(page, all_post_links)
#     109 print(f"\n({i}/{len(all_post_links)}) 📌 Navigating to: {post_url}")
#     111 response_received_flag[0] = False  # Reset before each visit
# --> 113 await page.goto(post_url, wait_until="networkidle")
#     114 await asyncio.sleep(1)  # Allow responses to load
#     116 # Wait dynamically for response interception (max 5 seconds)
#
# File ~/your-story/ig-project/.venv/lib/python3.13/site-packages/playwright/async_api/_generated.py:8987, in Page.goto(self, url, timeout, wait_until, referer)
#    8926 async def goto(
#    8927     self,
#    8928     url: str,
#    (...)   8934     referer: typing.Optional[str] = None,
#    8935 ) -> typing.Optional["Response"]:
#    8936     """Page.goto
#    8937
#    8938     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)   8983     Union[Response, None]
#    8984     """
#    8986     return mapping.from_impl_nullable(
# -> 8987         await self._impl_obj.goto(
#    8988             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8989         )
#    8990     )
#
# File ~/your-story/ig-project/.venv/lib/python3.13/site-packages/playwright/_impl/_page.py:552, in Page.goto(self, url, timeout, waitUntil, referer)
#     545 async def goto(
#     546     self,
#     547     url: str,
#    (...)    550     referer: str = None,
#     551 ) -> Optional[Response]:
# --> 552     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File ~/your-story/ig-project/.venv/lib/python3.13/site-packages/playwright/_impl/_frame.py:145, in Frame.goto(self, url, timeout, waitUntil, referer)
#     135 async def goto(
#     136     self,
#     137     url: str,
#    (...)    140     referer: str = None,
#     141 ) -> Optional[Response]:
#     142     return cast(
#     143         Optional[Response],
#     144         from_nullable_channel(
# --> 145             await self._channel.send("goto", locals_to_params(locals()))
#     146         ),
#     147     )
#
# File ~/your-story/ig-project/.venv/lib/python3.13/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/your-story/ig-project/.venv/lib/python3.13/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     526     return await cb()
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#     530     self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.instagram.com/daisychoiii/p/CrEJJwrLto2/", waiting until "networkidle"

# %%
len(data)
# data÷
# Out:
# 62

# %%
# save the data to a json file
with open('daisychoii_posts.json', 'w') as f:
    json.dump(data, f)
