# %%
import asyncio
import os
import json
import pandas as pd
from datetime import datetime
from playwright.async_api import async_playwright, TimeoutError
from dotenv import load_dotenv
import random

########## CONFIGURATION ##########

#set seed to unix timestamp
random.seed(int(datetime.now().timestamp()))

# Load environment variables
load_dotenv(override=True)
username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")

# Asyncio settings
# Set the maximum number of concurrent pages
MAX_PARALLEL_PAGES = 4
# Set the range for random jitter
# This is used to add a random delay before each request to avoid being blocked
JITTER_RANGE = (1, 2)


MAX_SCROLL_ATTEMPTS = 30
REPEAT_SCROLL_ELEMENTS_LIMIT = 5

GLOBAL_SEM = asyncio.Semaphore(MAX_PARALLEL_PAGES)

# %% [markdown]
# #######

# %%
build_shortcode_index("../scraper/ig_scraperv3/json/all_instagram_data.json")
# Out:
# 🔎 Built handle-lookup for 2963 shortcodes
# {'DIe1T1bg2Wf': 'cristiano',
#  'DIXBP7gA9uA': 'cristiano',
#  'DIL-t6qoUNX': 'cristiano',
#  'DIKJQTdgCtD': 'cristiano',
#  'DICffjKAj3o': 'cristiano',
#  'DH9ZbAnAUF2': 'cristiano',
#  'DH0eE6RgBLg': 'cristiano',
#  'DHy-NAqAJ-d': 'cristiano',
#  'DHj4YLnI0ui': 'cristiano',
#  'DHg6maaxCjL': 'cristiano',
#  'DHcDuWfIDRz': 'cristiano',
#  'DHZUBFdgBPP': 'cristiano',
#  'DHWttpnAWgt': 'cristiano',
#  'DHMegD4gG_E': 'cristiano',
#  'DHCGhubAPkQ': 'cristiano',
#  'DG8bD0Co7_6': 'cristiano',
#  'DG2yopigqIn': 'cristiano',
#  'DG1Rz95AIPn': 'cristiano',
#  'DGxqbv9oVTD': 'cristiano',
#  'DIUiaE9BgZJ': 'kyliejenner',
#  'DIP18DMva3s': 'kyliejenner',
#  'DH84u-TxBfT': 'kyliejenner',
#  'DHoSX0DJbf6': 'kyliejenner',
#  'DHl_kUwSh6_': 'kyliejenner',
#  'DHY1dVYJuf7': 'kyliejenner',
#  'DHWE1X4RQDV': 'kyliejenner',
#  'DHToGbyJKls': 'kyliejenner',
#  'DHRHD84RQL2': 'kyliejenner',
#  'DHPQkZupTmn': 'kyliejenner',
#  'DHOQFKpRpHg': 'kyliejenner',
#  'DHLmYtnxcWM': 'kyliejenner',
#  'DHJgU5Iv2v2': 'kyliejenner',
#  'DHCaYBBy9UD': 'kyliejenner',
#  'DG36MQeS7AK': 'kyliejenner',
#  'DGyqCm_ScoU': 'kyliejenner',
#  'DGw2qy8xbqy': 'kyliejenner',
#  'DGgh5D4yYbJ': 'kyliejenner',
#  'DGV_Jc0vdNm': 'kyliejenner',
#  'DGQlwEgJwyU': 'kyliejenner',
#  'DIbUvf_tfn0': 'leomessi',
#  'DIP-CCYon4B': 'leomessi',
#  'DH61Qm7t-cR': 'leomessi',
#  'DH6OK63J8eU': 'leomessi',
#  'DHzs2lFChH2': 'leomessi',
#  'DHwD6QfNjtM': 'leomessi',
#  'DHtel3Itry_': 'leomessi',
#  'DHhEmLkPcqI': 'leomessi',
#  'DHSD6idCIru': 'leomessi',
#  'DHKdPJpiuxU': 'leomessi',
#  'DGii7hitNnS': 'leomessi',
#  'DGdbQaqt0Dk': 'leomessi',
#  'DGZpRUQCoeh': 'leomessi',
#  'DGVrc3YN0j7': 'leomessi',
#  'DGT_RZftdo_': 'leomessi',
#  'DGR4FDEiEmr': 'leomessi',
#  'DGOQEk2N1Er': 'leomessi',
#  'DGJvFOyvhl1': 'leomessi',
#  'DGGL6V-Ny-n': 'leomessi',
#  'DGFAwajCFJE': 'leomessi',
#  'DGjpGxXyNEZ': 'zendaya',
#  'DBKF41CSTku': 'zendaya',
#  'C_Z7HlNxM82': 'zendaya',
#  'C6HPA2jxG4Q': 'zendaya',
#  'C5kXzTKL-tW': 'zendaya',
#  'C4GgNmGPRHc': 'zendaya',
#  'C1ktjOMLWt1': 'zendaya',
#  'Cx_L3TCvETx': 'zendaya',
#  'Cx8FBWbL1xu': 'zendaya',
#  'Cx5f2bBr4t_': 'zendaya',
#  'CxBfqorPmv1': 'zendaya',
#  'Cws8YkCPkzs': 'zendaya',
#  'Cws49u1vmPn': 'zendaya',
#  'CwreDnMuivO': 'zendaya',
#  'Cvaft3SL4Zr': 'zendaya',
#  'CvA07ccLh0r': 'zendaya',
#  'CspIdI4v4Rv': 'zendaya',
#  'Csb1vShPjeA': 'zendaya',
#  'Cr1QZehPCZE': 'zendaya',
#  'Crv2TFiRtO8': 'zendaya',
#  'DIFfuoltYpj': 'selenagomez',
#  'DHtEV1JxY9e': 'selenagomez',
#  'DHqyEKlx45m': 'selenagomez',
#  'DHoNgIfR1Eh': 'selenagomez',
#  'DHlohKvRqNM': 'selenagomez',
#  'DHjDszdxA7k': 'selenagomez',
#  'DHgfCKYRC_I': 'selenagomez',
#  'DHcnxrRtIeC': 'selenagomez',
#  'DHbEvV8xKI9': 'selenagomez',
#  'DHa52pVxzb5': 'selenagomez',
#  'DHL7ZOTRe0a': 'selenagomez',
#  'DHL6080RCqp': 'selenagomez',
#  'DHL6SmFxbir': 'selenagomez',
#  'DHKpuJEtril': 'selenagomez',
#  'DHEKKMBx517': 'selenagomez',
#  'DG9OzMFSjNZ': 'selenagomez',
#  'DGyPcgspxTb': 'selenagomez',
#  'DGwlnGNtU8S': 'selenagomez',
#  'DGdnid9vW6-': 'selenagomez',
#  'DGUF_ZoyCdv': 'selenagomez',
#  'DCEi-cGtXAw': 'virat.kohli',
#  'C8_ohdORG-n': 'virat.kohli',
#  'C82UlomxBy9': 'virat.kohli',
#  'C80EI7NNDFK': 'virat.kohli',
#  'C7WXPJINqc0': 'virat.kohli',
#  'C6bGvvzvQma': 'virat.kohli',
#  'C3kvKa5Nr6m': 'virat.kohli',
#  'C0vlL2-PsKy': 'virat.kohli',
#  'C0vRPnvoIAa': 'virat.kohli',
#  'Cx71_fitoxz': 'virat.kohli',
#  'CwMfpUrNzrY': 'virat.kohli',
#  'CwFNTdVNzed': 'virat.kohli',
#  'CwEbWBGo-PW': 'virat.kohli',
#  'CvesOs2uOcm': 'virat.kohli',
#  'CutzUYmv1kk': 'virat.kohli',
#  'CufDoNuNe1a': 'virat.kohli',
#  'CueUzxluh5a': 'virat.kohli',
#  'CucwNpIvK4P': 'virat.kohli',
#  'CuMgpWRrx2g': 'virat.kohli',
#  'Ct1wf30tTcu': 'virat.kohli',
#  'DIbYn6FJn-y': 'beyonce',
#  'DGEuwIrRUbP': 'beyonce',
#  'DF_9CLwxoo4': 'beyonce',
#  'DFtCWZaTshd': 'beyonce',
#  'DFmh0bqRmgm': 'beyonce',
#  'DFjySCzxihd': 'beyonce',
#  'DEyxvGYx8aB': 'beyonce',
#  'DDYcs7fpqqi': 'beyonce',
#  'DCvDClJSEjd': 'beyonce',
#  'DCIQ0YiyBAI': 'beyonce',
#  'DCAlgG1y015': 'beyonce',
#  'DB-14k-RTqu': 'beyonce',
#  'DB5pcPkxoCg': 'beyonce',
#  'DB2aWEeymfr': 'beyonce',
#  'DB0TwsBxihF': 'beyonce',
#  'DBtU05Qv5h7': 'beyonce',
#  'DBsl44URC6i': 'beyonce',
#  'DBnAzIEP8Gb': 'beyonce',
#  'DBg_ULES3C8': 'beyonce',
#  'DBUfcE5yQAv': 'beyonce',
#  'DIRS4bAplzG': 'kimkardashian',
#  'DIPuoaSSopy': 'kimkardashian',
#  'DIH7aZpyIT5': 'kimkardashian',
#  'DIChoxpSVHQ': 'kimkardashian',
#  'DH_dcP5ppZx': 'kimkardashian',
#  'DH6rtWQBxkF': 'kimkardashian',
#  'DHzAw2GS4_y': 'kimkardashian',
#  'DHrmdOyS7n-': 'kimkardashian',
#  'DHn_iS4px9i': 'kimkardashian',
#  'DHULYROSPbL': 'kimkardashian',
#  'DHSbbTtxp05': 'kimkardashian',
#  'DHMbA0MSj1H': 'kimkardashian',
#  'DHL_cMapJN7': 'kimkardashian',
#  'DHLz3ehJA6o': 'kimkardashian',
#  'DHKG7pYSgv-': 'kimkardashian',
#  'DG3ZKRVvMq7': 'kimkardashian',
#  'DGyTCSuSwkz': 'kimkardashian',
#  'DGvqz2MP4L7': 'kimkardashian',
#  'DGvbhFNpHvs': 'kimkardashian',
#  'DGsI__tR7mw': 'kimkardashian',
#  'DFsAkVEN8Cw': 'tomholland2013',
#  'DD5JWadTVtZ': 'tomholland2013',
#  'DBj0oRitE-M': 'tomholland2013',
#  'DBd6JGyN80R': 'tomholland2013',
#  'DBFIJ0StI5B': 'tomholland2013',
#  'DAET830tv17': 'tomholland2013',
#  'C_gUrFoSjoi': 'tomholland2013',
#  'C_NjVqANJRu': 'tomholland2013',
#  'C-kGalyNHgq': 'tomholland2013',
#  'C9FD2uANo2X': 'tomholland2013',
#  'C7CTAd3N18p': 'tomholland2013',
#  'C67Uk4qqdPj': 'tomholland2013',
#  'C66yN-ANSC_': 'tomholland2013',
#  'C6qjI_MN0_d': 'tomholland2013',
#  'C6RUDAsNRHa': 'tomholland2013',
#  'C6Bly7btynW': 'tomholland2013',
#  'C3bRC6Btus3': 'tomholland2013',
#  'C3APDxbt3ov': 'tomholland2013',
#  'C2Yf5kZpum5': 'tomholland2013',
#  'C2JjjnLLL4J': 'tomholland2013',
#  'DIaPpp9z7Wq': 'sooyaaa__',
#  'DIX8nCBpjYY': 'sooyaaa__',
#  'DIJGGzIp_M9': 'sooyaaa__',
#  'DH_OVJQpBsM': 'sooyaaa__',
#  'DH_AVl6J4-3': 'sooyaaa__',
#  'DH7SrJJPyCx': 'sooyaaa__',
#  'DH1Ch34zp_-': 'sooyaaa__',
#  'DHyhk84JaDA': 'sooyaaa__',
#  'DHmcWcxTBT7': 'sooyaaa__',
#  'DHgcRhEJA60': 'sooyaaa__',
#  'DHdTNv_pmJN': 'sooyaaa__',
#  'DHcRRUdTUV2': 'sooyaaa__',
#  'DHaxuCqpD65': 'sooyaaa__',
#  'DHSgMKApYAv': 'sooyaaa__',
#  'DHQULHOp-x7': 'sooyaaa__',
#  'DHD9vRDpf4Y': 'sooyaaa__',
#  'DG_NfVfzFyh': 'sooyaaa__',
#  'DG7Zq1HJaSk': 'sooyaaa__',
#  'DG2oC48Jest': 'sooyaaa__',
#  'DG2hGouJm1Z': 'sooyaaa__',
#  'DG0unqrIpNv': 'sooyaaa__',
#  'DGzuzS_pCW_': 'sooyaaa__',
#  'DGy7LnytDZn': 'sooyaaa__',
#  'DGtBxDdzPob': 'sooyaaa__',
#  'DGkZcPrp0uc': 'sooyaaa__',
#  'DGh35rvpATm': 'sooyaaa__',
#  'DGaJKtnJjo_': 'sooyaaa__',
#  'DGScwLepjZ2': 'sooyaaa__',
#  'DGPxL7npnQq': 'sooyaaa__',
#  'DGMolUfPa7u': 'sooyaaa__',
#  'DGIlrsppJGI': 'sooyaaa__',
#  'DGIgzXJpSaD': 'sooyaaa__',
#  'DGF60Rjpx5S': 'sooyaaa__',
#  'DGDscKEvWnj': 'sooyaaa__',
#  'DGBICQkp4uF': 'sooyaaa__',
#  'DF-iBB8puSF': 'sooyaaa__',
#  'DFzI39PpPWp': 'sooyaaa__',
#  'DFxL06Cp_x4': 'sooyaaa__',
#  'DFvIGSQTapp': 'sooyaaa__',
#  'DFsh-pdzeig': 'sooyaaa__',
#  'DFp8wclPR9x': 'sooyaaa__',
#  'DFotZOMJIr9': 'sooyaaa__',
#  'DFnXQ6kPH-X': 'sooyaaa__',
#  'DFnW6JUPVbO': 'sooyaaa__',
#  'DFiNPf2PKHt': 'sooyaaa__',
#  'DFfpBPgTCVH': 'sooyaaa__',
#  'DFdDtFKTzFe': 'sooyaaa__',
#  'DFVzhFBzVFL': 'sooyaaa__',
#  'DFVpvNgzwA3': 'sooyaaa__',
#  'DFSxDyCvKSa': 'sooyaaa__',
#  'DIRdBlsyGKS': 'bebiisan',
#  'DB6vRMEy9cz': 'bebiisan',
#  'C_XEadDOZ26': 'bebiisan',
#  'C9bA4xCvdQ-': 'bebiisan',
#  'C8kkXO0P6d4': 'bebiisan',
#  'C7zpabtyVOy': 'bebiisan',
#  'C7STs2tSbC3': 'bebiisan',
#  'CxD6oztpXqc': 'bebiisan',
#  'CvqBP4kywAq': 'bebiisan',
#  'CtAQH33SETv': 'bebiisan',
#  'CsdFDOqO56h': 'bebiisan',
#  'CqmwRSkuqQv': 'bebiisan',
#  'CqLsrBUPvFX': 'bebiisan',
#  'Co6LEglrWv_': 'bebiisan',
#  'CobOtI0r00a': 'bebiisan',
#  'CoI217hPmUK': 'bebiisan',
#  'DIXlF3yv0e2': 'jang.hayden',
#  'DHEhuRPSqch': 'jang.hayden',
#  'DFeobSjxLd6': 'jang.hayden',
#  'DEQQvGwvVBT': 'jang.hayden',
#  'DBwih0QyjKD': 'jang.hayden',
#  'DAj3NG_SOTb': 'jang.hayden',
#  'DAMuGsVy7JX': 'jang.hayden',
#  'C-qXRilyItS': 'jang.hayden',
#  'C9Q3EaBPHmX': 'jang.hayden',
#  'C8uv-Arv5rG': 'jang.hayden',
#  'C8Vxr23pRd4': 'jang.hayden',
#  'C8L8OpyOX41': 'jang.hayden',
#  'C7xF4BoyNCH': 'jang.hayden',
#  'C5Wh26ivrLj': 'jang.hayden',
#  'C5J1jAmv_vm': 'jang.hayden',
#  'C44I5UJP1-p': 'jang.hayden',
#  'C2_wf30Pgby': 'jang.hayden',
#  'C2uhBfzLZlR': 'jang.hayden',
#  'C1xsX1svx14': 'jang.hayden',
#  'C1sZCxFyLyj': 'jang.hayden',
#  'C1dkGvuLtVE': 'jang.hayden',
#  'C0XaXLbS7N5': 'jang.hayden',
#  'CwWtYGOLSZ8': 'jang.hayden',
#  'Cv5T-PdvYQE': 'jang.hayden',
#  'Cvkh4h6pqKE': 'jang.hayden',
#  'CufmM9GPoME': 'jang.hayden',
#  'CtdDJrmrDSO': 'jang.hayden',
#  'CtNQtxDPve7': 'jang.hayden',
#  'Cs9papuyjDR': 'jang.hayden',
#  'CqG1RJBP00t': 'jang.hayden',
#  'Cpdb2uwvfIh': 'jang.hayden',
#  'CnfyNJHPsPW': 'jang.hayden',
#  'CnVgjl_Pjr1': 'jang.hayden',
#  'DIaGDmGSKMW': 'valentinoxdior',
#  'DIRZb8Dx-D_': 'valentinoxdior',
#  'DH_YwciRnhI': 'valentinoxdior',
#  'DHyxeh1xajn': 'valentinoxdior',
#  'DHv8uK_Rhos': 'valentinoxdior',
#  'DHlpamVR3Tg': 'valentinoxdior',
#  'DHRC3ioR9dW': 'valentinoxdior',
#  'DHELELSRb7d': 'valentinoxdior',
#  'DG05zUrx3f6': 'valentinoxdior',
#  'DGn79i0xSJV': 'valentinoxdior',
#  'DGiy6iux_yj': 'valentinoxdior',
#  'DGTVqRPieBb': 'valentinoxdior',
#  'DF-wROCx3YF': 'valentinoxdior',
#  'DFvUAe3xoNW': 'valentinoxdior',
#  'DFqJpYSRaPC': 'valentinoxdior',
#  'DFf4I0LP1IJ': 'valentinoxdior',
#  'DFYHzTuRwDc': 'valentinoxdior',
#  'DFN16i3x7Yt': 'valentinoxdior',
#  'DFA9AeZxSWw': 'valentinoxdior',
#  'DE2pX4mPM6Q': 'valentinoxdior',
#  'DExf_zAR2Lm': 'valentinoxdior',
#  'DEpyaDPx288': 'valentinoxdior',
#  'DEfd86dxdVL': 'valentinoxdior',
#  'DEVLIeSxoLq': 'valentinoxdior',
#  'DEK36yKxaq-': 'valentinoxdior',
#  'DEDJcuexss1': 'valentinoxdior',
#  'DDfHDnwR_xI': 'valentinoxdior',
#  'DDZ8jR4RiY8': 'valentinoxdior',
#  'DDSOzF0xSLK': 'valentinoxdior',
#  'DDNEc-RRCR3': 'valentinoxdior',
#  'DCzVNotRfPQ': 'valentinoxdior',
#  'DCXAC-OxvcU': 'valentinoxdior',
#  'DCCayzixndj': 'valentinoxdior',
#  'DBrGxz0Rt-B': 'valentinoxdior',
#  'DBg0dkHRRbN': 'valentinoxdior',
#  'DBZF6EWxjJE': 'valentinoxdior',
#  'DBRXrTPx0kj': 'valentinoxdior',
#  'DBJpVqJxAj8': 'valentinoxdior',
#  'DAd3MtxRV3N': 'valentinoxdior',
#  'DAWJfD0xfzO': 'valentinoxdior',
#  'DAObJheyxAB': 'valentinoxdior',
#  'DABir_vyWYS': 'valentinoxdior',
#  'C_yG3DcROeM': 'valentinoxdior',
#  'C_gEsRGx5sk': 'valentinoxdior',
#  'C_BMcuBRJFk': 'valentinoxdior',
#  'C-24A1dRRM_': 'valentinoxdior',
#  'C-slIxIRRnG': 'valentinoxdior',
#  'C-YCLeJR3sl': 'valentinoxdior',
#  'C-F86LWRfks': 'valentinoxdior',
#  'C9-OjvhRxza': 'valentinoxdior',
#  'DIeYz86q296': 'jaycee_yg',
#  'DHobH3gK44G': 'jaycee_yg',
#  'DHRP3AQqTkR': 'jaycee_yg',
#  'DHEX_MpqMxK': 'jaycee_yg',
#  'DG6KW7CNxqg': 'jaycee_yg',
#  'DGOFeonqTrK': 'jaycee_yg',
#  'DFaql_No3b0': 'jaycee_yg',
#  'DDpZc1_Jae1': 'jaycee_yg',
#  'DDPpncpqB2h': 'jaycee_yg',
#  'DDFWma2qTBz': 'jaycee_yg',
#  'DCUZblUKwXX': 'jaycee_yg',
#  'DB6qvEoq_nn': 'jaycee_yg',
#  'DBZQhFKKhQK': 'jaycee_yg',
#  'DA84KIpK3tX': 'jaycee_yg',
#  'DAoSAI7KHKY': 'jaycee_yg',
#  'DAgciECqOIG': 'jaycee_yg',
#  'DAY1DToqdJe': 'jaycee_yg',
#  'DAQ-rg7qfNX': 'jaycee_yg',
#  'DABmd0mT2V5': 'jaycee_yg',
#  'C_lV8KWq_EL': 'jaycee_yg',
#  'C_Gi6aKKK6c': 'jaycee_yg',
#  'C-24DPkq-vd': 'jaycee_yg',
#  'C9-OkdVqC7Q': 'jaycee_yg',
#  'C9csuafKt7K': 'jaycee_yg',
#  'C9Fr30LqQll': 'jaycee_yg',
#  'C8mlbbIK7IF': 'jaycee_yg',
#  'C8UqkRupvi1': 'jaycee_yg',
#  'C7zLrh-KXF5': 'jaycee_yg',
#  'C7b2KK0KBeZ': 'jaycee_yg',
#  'C7J7al1qkX2': 'jaycee_yg',
#  'C6WaYo7qfca': 'jaycee_yg',
#  'C56AQZ6qXmk': 'jaycee_yg',
#  'C5EA7r0JFIB': 'jaycee_yg',
#  'C4vl9XWq4l6': 'jaycee_yg',
#  'C4qkD_AK6Un': 'jaycee_yg',
#  'C4JLCXbpO_c': 'jaycee_yg',
#  'C3YFJ8WKYKn': 'jaycee_yg',
#  'C3QWqhTKJuX': 'jaycee_yg',
#  'C2-YVs7qmoM': 'jaycee_yg',
#  'C2c4n3GK2ZG': 'jaycee_yg',
#  'C2VEoPnK5eW': 'jaycee_yg',
#  'C1xEVj1Krdk': 'jaycee_yg',
#  'C1AS3RYqK3R': 'jaycee_yg',
#  'C04czWRKOjX': 'jaycee_yg',
#  'C0riWmEK8GZ': 'jaycee_yg',
#  'C0RzDNSKScV': 'jaycee_yg',
#  'C0HVS_NqUd5': 'jaycee_yg',
#  'CzMFP01KTMC': 'jaycee_yg',
#  'CyoGEpaq5-8': 'jaycee_yg',
#  'Cyd0Ps1qAIO': 'jaycee_yg',
#  'DBdQ7EWSKxW': 'smokinghotvirgin',
#  'C6snowzLhsR': 'smokinghotvirgin',
#  'C0gAjInrzb4': 'smokinghotvirgin',
#  'DIMUIzCyNv2': 'smokinghotvirgin',
#  'DH6L4LiywMz': 'smokinghotvirgin',
#  'DH3YqI1y6_w': 'smokinghotvirgin',
#  'DHqVBdGyKh5': 'smokinghotvirgin',
#  'DHogJvWSaiI': 'smokinghotvirgin',
#  'DHihx93SGrF': 'smokinghotvirgin',
#  'DHf2useSd2m': 'smokinghotvirgin',
#  'DHVoaxly35X': 'smokinghotvirgin',
#  'DHQG3pky1Q6': 'smokinghotvirgin',
#  'DHGRgAGyQm5': 'smokinghotvirgin',
#  'DGsUOr4Su69': 'smokinghotvirgin',
#  'DGsFOnNSVTM': 'smokinghotvirgin',
#  'DGcU9WJShGx': 'smokinghotvirgin',
#  'DGNopQnS_b3': 'smokinghotvirgin',
#  'DF7WTYRyBlw': 'smokinghotvirgin',
#  'DF0FhGeym9Z': 'smokinghotvirgin',
#  'DFz1mCzSr5f': 'smokinghotvirgin',
#  'DFo_s44SGCX': 'smokinghotvirgin',
#  'DFe8eYSSlOA': 'smokinghotvirgin',
#  'DFAuwduSY-S': 'smokinghotvirgin',
#  'DEz6nvCSJev': 'smokinghotvirgin',
#  'DEkJqyDy81s': 'smokinghotvirgin',
#  'DEhD2WwyN3-': 'smokinghotvirgin',
#  'DEgqaybSriS': 'smokinghotvirgin',
#  'DEEoHsCywLe': 'smokinghotvirgin',
#  'DD69osFSXCR': 'smokinghotvirgin',
#  'DD6Dl2GyLY9': 'smokinghotvirgin',
#  'DD2Bx0UyoSd': 'smokinghotvirgin',
#  'DDuYCloS20u': 'smokinghotvirgin',
#  'DDmxxWtyQPs': 'smokinghotvirgin',
#  'DDl2z5fSJ6g': 'smokinghotvirgin',
#  'DDkjLF7BPZr': 'smokinghotvirgin',
#  'DDhBqsvSSgV': 'smokinghotvirgin',
#  'DDY6SVfScn_': 'smokinghotvirgin',
#  'DDJR1AkS4hX': 'smokinghotvirgin',
#  'DCwHQ6jyw6g': 'smokinghotvirgin',
#  'DCtU4upSDw6': 'smokinghotvirgin',
#  'DCorKexyUUq': 'smokinghotvirgin',
#  'DCbsq4Ayuoo': 'smokinghotvirgin',
#  'DCawPmFSUDC': 'smokinghotvirgin',
#  'DCZHOvHyNYl': 'smokinghotvirgin',
#  'DCRov6Ay4MQ': 'smokinghotvirgin',
#  'DCHNhYdSDcT': 'smokinghotvirgin',
#  'DCHLWNvSb_H': 'smokinghotvirgin',
#  'DCBdYY7S-h6': 'smokinghotvirgin',
#  'DB_KpDWSZpO': 'smokinghotvirgin',
#  'DBqaqZFye1P': 'smokinghotvirgin',
#  'DG_DBfTswnn': 'reubsfits',
#  'DF0nHNmI8Dc': 'reubsfits',
#  'DEQXF0RIwZo': 'reubsfits',
#  'DD7WzZgIZ5x': 'reubsfits',
#  'DDZ-kx_o54j': 'reubsfits',
#  'DDU1ylBIiNA': 'reubsfits',
#  'DCM1wNwo140': 'reubsfits',
#  'DBEWj-yII1R': 'reubsfits',
#  'C8PnKekIeqa': 'reubsfits',
#  'C7XAyaroWK5': 'reubsfits',
#  'DIeR4VPM8aB': 'chiprooma',
#  'DHMNXPjMZPv': 'chiprooma',
#  'DHG13i1tNRC': 'chiprooma',
#  'DG54-oDsnhs': 'chiprooma',
#  'DGYfs_YMs4k': 'chiprooma',
#  'DE5FxQjM6Qs': 'chiprooma',
#  'DEnFjlmsa59': 'chiprooma',
#  'DEc4nHvMIxw': 'chiprooma',
#  'DEVEJNFMwI8': 'chiprooma',
#  'DDxKRzgOnvX': 'chiprooma',
#  'DDhxLW3OaHQ': 'chiprooma',
#  'DCesuTaMFil': 'chiprooma',
#  'DBuLOhnuhCa': 'chiprooma',
#  'C_gNkEqMUyo': 'chiprooma',
#  'C-YVRe6urEf': 'chiprooma',
#  'C9c4fuqsVw-': 'chiprooma',
#  'C9KkaW-MJfB': 'chiprooma',
#  'C896auEMyJ-': 'chiprooma',
#  'C5dtl7PMoUz': 'chiprooma',
#  'C5Jez2IM_ta': 'chiprooma',
#  'C452-4lsB9Y': 'chiprooma',
#  'C4D5KIGMof_': 'chiprooma',
#  'C2-tJPwMIym': 'chiprooma',
#  'C2P5wlzMlKQ': 'chiprooma',
#  'C1SGdgcMLQS': 'chiprooma',
#  'C1M6MRbML0E': 'chiprooma',
#  'C09bYWcMm3r': 'chiprooma',
#  'C0Hi78-MCaw': 'chiprooma',
#  'CzOytYFM0oD': 'chiprooma',
#  'CyY6n3HMvFi': 'chiprooma',
#  'CyEBQsEs-bn': 'chiprooma',
#  'Cx27mj4sqL3': 'chiprooma',
#  'CvVRLVeMp7I': 'chiprooma',
#  'Cn-UR8XMdQp': 'chiprooma',
#  'DIWtH0hP-CR': 'trentinvuong',
#  'DIHQbvcPuN9': 'trentinvuong',
#  'DH6TIzzpcJw': 'trentinvuong',
#  'DHjICO-p2C5': 'trentinvuong',
#  'DHWI5wpvFX4': 'trentinvuong',
#  'DHQ852KJVcp': 'trentinvuong',
#  'DG8jlHlPxRv': 'trentinvuong',
#  'DGqgC6Du1Nh': 'trentinvuong',
#  'DGYei3jPMlK': 'trentinvuong',
#  'DGLjZsMP6Lv': 'trentinvuong',
#  'DF0XGcdPgrv': 'trentinvuong',
#  'DFndjHJJYuJ': 'trentinvuong',
#  'DFVePZ8g_xh': 'trentinvuong',
#  'DE7zX0cz2cz': 'trentinvuong',
#  'DEflCfiyRBT': 'trentinvuong',
#  'DEKw9zZJCfE': 'trentinvuong',
#  'DD7UKvbyjjg': 'trentinvuong',
#  'DDm65duPu0U': 'trentinvuong',
#  'DDUyrpNvg2i': 'trentinvuong',
#  'DDAXOxmSlUM': 'trentinvuong',
#  'DCrl0-Hvgx6': 'trentinvuong',
#  'DB6tu_4O_rf': 'trentinvuong',
#  'DBoqp-ByDMg': 'trentinvuong',
#  'DBWp2uuSc0t': 'trentinvuong',
#  'DBEdcYgvdwG': 'trentinvuong',
#  'DAyki7fS9wM': 'trentinvuong',
#  'DAghuC8O3K1': 'trentinvuong',
#  'DAOfvJ6vao8': 'trentinvuong',
#  'C_8lKXdPJqa': 'trentinvuong',
#  'C_YdHTnvn7G': 'trentinvuong',
#  'C_Gf12OPlcm': 'trentinvuong',
#  'C-0fPU3u0mF': 'trentinvuong',
#  'C-QJOKzOBs9': 'trentinvuong',
#  'C9-ipu-yBDp': 'trentinvuong',
#  'C9sWJBJu2Fo': 'trentinvuong',
#  'C9abgX0y10x': 'trentinvuong',
#  'C9IWyE3PblV': 'trentinvuong',
#  'C82IT2fJbs3': 'trentinvuong',
#  'C8kSOBHPleZ': 'trentinvuong',
#  'C8ScD4hunBK': 'trentinvuong',
#  'C8AXGkIvcjM': 'trentinvuong',
#  'C7uKf2ppu4z': 'trentinvuong',
#  'C7J-2gTrsWo': 'trentinvuong',
#  'C64E4BRxoD5': 'trentinvuong',
#  'C6mOAcPvi9N': 'trentinvuong',
#  'C6T-CM6Rqg9': 'trentinvuong',
#  'C6CAC_4RSXd': 'trentinvuong',
#  'C5wDLbTvXuD': 'trentinvuong',
#  'C5d7wHduGuk': 'trentinvuong',
#  'C5L9y7ZpFEW': 'trentinvuong',
#  'C46BQ1xJtaS': 'trentinvuong',
#  'C4nzgdWu3Lh': 'trentinvuong',
#  'C4V33MSxcGI': 'trentinvuong',
#  'C4LmaqjJHvc': 'trentinvuong',
#  'C35hW3QPr4z': 'trentinvuong',
#  'C3nf2RFuJjv': 'trentinvuong',
#  'C2p6hHVrEOj': 'trentinvuong',
#  'C2X6ybsP-e_': 'trentinvuong',
#  'C2F3SR0rj1Z': 'trentinvuong',
#  'C1z5LUcv9NW': 'trentinvuong',
#  'C1h4iOspXPV': 'trentinvuong',
#  'C1P7oG0PAfm': 'trentinvuong',
#  'C0w8T5RvBI-': 'trentinvuong',
#  'C0M1-7iL7kX': 'trentinvuong',
#  'Cz64UvgPDOw': 'trentinvuong',
#  'CzjiWxUO9Gh': 'trentinvuong',
#  'CzMfXy6Pzj1': 'trentinvuong',
#  'CzCSIVxPTiO': 'trentinvuong',
#  'CywCiJ5ulgS': 'trentinvuong',
#  'CybcJkyLnty': 'trentinvuong',
#  'CyJaiGcrQgT': 'trentinvuong',
#  'Cx_HW9VLBnM': 'trentinvuong',
#  'Cxn9NqYup4r': 'trentinvuong',
#  'CxgNyvCrMfV': 'trentinvuong',
#  'CxOKyvWxhQA': 'trentinvuong',
#  'CxJCqn3O2-N': 'trentinvuong',
#  'Cw5l-KLOJeX': 'trentinvuong',
#  'CwvStybrPOx': 'trentinvuong',
#  'CwasYOduRmo': 'trentinvuong',
#  'CwN0ZVKr0u0': 'trentinvuong',
#  'Cvu60qkLGa-': 'trentinvuong',
#  'CvpqcD_uECL': 'trentinvuong',
#  'CvfXNVKuHz7': 'trentinvuong',
#  'CvAsAjmPgQE': 'trentinvuong',
#  'CuztKAbPxzM': 'trentinvuong',
#  'Cur-KPCuqhM': 'trentinvuong',
#  'CuZ8mkZOqjH': 'trentinvuong',
#  'CuUzGFXO5RZ': 'trentinvuong',
#  'CuPs3x6rNgQ': 'trentinvuong',
#  'CtmmswvvLy7': 'trentinvuong',
#  'CtFLi7KSlAa': 'trentinvuong',
#  'Csb6IQkvpr2': 'trentinvuong',
#  'CsCVC_UPUnE': 'trentinvuong',
#  'Cq6OmHTP6lN': 'trentinvuong',
#  'CoiTThcSQPG': 'trentinvuong',
#  'DH9DMiRxAQt': 'zaycamm',
#  'DIRpJNEI12g': 'zaycamm',
#  'DIJnwMpoUK_': 'zaycamm',
#  'DIHOK-aoxQy': 'zaycamm',
#  'DH3kTwHRFgn': 'zaycamm',
#  'DHll37hxQVX': 'zaycamm',
#  'DHYv3nSx4yu': 'zaycamm',
#  'DHTkqMlRgqs': 'zaycamm',
#  'DHRAw4uR-Sg': 'zaycamm',
#  'DHG1yGPxU1M': 'zaycamm',
#  'DHEVIo0xEfP': 'zaycamm',
#  'DGtYgdiRKMc': 'zaycamm',
#  'DGlgh5sR0Ba': 'zaycamm',
#  'DGisEnfCecc': 'zaycamm',
#  'DGOGam8x-0M': 'zaycamm',
#  'DF-kP6bx6wG': 'zaycamm',
#  'DFxyiKJRg8z': 'zaycamm',
#  'DFiGIdtIaCo': 'zaycamm',
#  'DFdOjbCI7KK': 'zaycamm',
#  'DFLX1PgoUro': 'zaycamm',
#  'DEXtQ_qR2mi': 'zaycamm',
#  'DEIUEd9RjHn': 'zaycamm',
#  'DEDDoV2R86t': 'zaycamm',
#  'DDue8RoxXiq': 'zaycamm',
#  'DDVBYJYxuXi': 'zaycamm',
#  'DC-DXv2xR6T': 'zaycamm',
#  'DC3CCY9NJ7Y': 'zaycamm',
#  'DC15kWZx3VY': 'zaycamm',
#  'DCw1yKqRjTP': 'zaycamm',
#  'DCce7JWTvk4': 'zaycamm',
#  'DCSJgS8vsOx': 'zaycamm',
#  'DCMnJbNRwZi': 'zaycamm',
#  'DCE6U_DRCLc': 'zaycamm',
#  'DB1iHj_RmpT': 'zaycamm',
#  'DBbmv2qvNNH': 'zaycamm',
#  'DBT2XQWP7ga': 'zaycamm',
#  'DBPbLNqPBuz': 'zaycamm',
#  'DBB7P0YRAs4': 'zaycamm',
#  'DAyfoj_vyio': 'zaycamm',
#  'DAgXQiTvtE6': 'zaycamm',
#  'DAJPWPsPf3A': 'zaycamm',
#  'DABl4-ev6yv': 'zaycamm',
#  'C_3WMm6P0Kg': 'zaycamm',
#  'C_yDTOpP3h8': 'zaycamm',
#  'C_f_-f2JM7T': 'zaycamm',
#  'C_GO_DdJzFd': 'zaycamm',
#  'C-p9RzRJZ_-': 'zaycamm',
#  'C-S24wkJUt0': 'zaycamm',
#  'C95DZ0vJ_pO': 'zaycamm',
#  'C9sI8muJJKy': 'zaycamm',
#  'C9aLsn8JElK': 'zaycamm',
#  'C87NABxsXfr': 'zaycamm',
#  'C7zMrQ0J_4U': 'zaycamm',
#  'C7E2fypuXDE': 'zaycamm',
#  'C6G7qLGudMx': 'zaycamm',
#  'C5TdLUML_4h': 'zaycamm',
#  'C4lJCP8MFNt': 'zaycamm',
#  'C4GXy_oLVAJ': 'zaycamm',
#  'C3nfz3VMdUQ': 'zaycamm',
#  'C3VfYZKrhOz': 'zaycamm',
#  'C27xfaduz56': 'zaycamm',
#  'C2z_tZrOMyr': 'zaycamm',
#  'C2aYEFNpHKN': 'zaycamm',
#  'C2SbAasucqn': 'zaycamm',
#  'C2AgBmQsmnF': 'zaycamm',
#  'C0SUztpP9YV': 'zaycamm',
#  'CzJ0hBkJi5h': 'zaycamm',
#  'Cwqmw7Dv8BF': 'zaycamm',
#  'DIhXRK_T1Yh': 'jakewebber9',
#  'DIetQ3azw3D': 'jakewebber9',
#  'DIUoKPThfjW': 'jakewebber9',
#  'DINN7GcvD0P': 'jakewebber9',
#  'DHujolRJTSy': 'jakewebber9',
#  'DHeTytDyDka': 'jakewebber9',
#  'DGjyEFDpne6': 'jakewebber9',
#  'DGbUVKwvBx1': 'jakewebber9',
#  'DEIt_OYTcqZ': 'jakewebber9',
#  'DDAfWBUyeOl': 'jakewebber9',
#  'DBr_DwySFtc': 'jakewebber9',
#  'DBaRFbvpfqm': 'jakewebber9',
#  'DBWrahiSzX2': 'jakewebber9',
#  'C_qrndCsRYl': 'jakewebber9',
#  'C_dx1oFyDQn': 'jakewebber9',
#  'C_O-Pb7SRlB': 'jakewebber9',
#  'C9n3S4YysG0': 'jakewebber9',
#  'C8JB0gzpclu': 'jakewebber9',
#  'C7M-_MXSJfN': 'jakewebber9',
#  'C6_-1_-vlMm': 'jakewebber9',
#  'C6o-75kS8gw': 'jakewebber9',
#  'C5wb-lLSguN': 'jakewebber9',
#  'C41b1JEPCBC': 'jakewebber9',
#  'C4vr7nQvmyh': 'jakewebber9',
#  'C3yYiKgvzmP': 'jakewebber9',
#  'C3lN2ZHPCUA': 'jakewebber9',
#  'C3Lg97KPKvk': 'jakewebber9',
#  'C3KCmo7uEFC': 'jakewebber9',
#  'C2lGlSCvPL7': 'jakewebber9',
#  'C15SuiTSZK3': 'jakewebber9',
#  'C1pxD3Nyi4O': 'jakewebber9',
#  'C1Xi14dP0lR': 'jakewebber9',
#  'C1Ig2ocPyIr': 'jakewebber9',
#  'C0cyYTGP53p': 'jakewebber9',
#  'C0VO3NPJIDR': 'jakewebber9',
#  'C0PqgQ_yjve': 'jakewebber9',
#  'CzZSJAcPsjM': 'jakewebber9',
#  'Cyr4uRur8Wy': 'jakewebber9',
#  'Cx08KXgpwva': 'jakewebber9',
#  'CxQw47mv44-': 'jakewebber9',
#  'CwgCzYlvnfA': 'jakewebber9',
#  'Cv8w-kxrFZM': 'jakewebber9',
#  'Cvngvl1vk7b': 'jakewebber9',
#  'CuXTJW_uzjI': 'nicolassturniolo',
#  'DIcdou_yWB9': 'kirstentitus',
#  'DIZ3O0By4ck': 'kirstentitus',
#  'DIZmSkHzoby': 'kirstentitus',
#  'DIXgHVjPMFo': 'kirstentitus',
#  'DH4uhlHvZqH': 'kirstentitus',
#  'DHesk2YSrHR': 'kirstentitus',
#  'DGl_G7EymJ8': 'kirstentitus',
#  'DEdTSMvTF7f': 'kirstentitus',
#  'DETb4nOSXra': 'kirstentitus',
#  'DCvCzrLS9JR': 'kirstentitus',
#  'DCNJjmBzPP6': 'kirstentitus',
#  'DAbkEMES_Dk': 'kirstentitus',
#  'C88TNHcvlDw': 'kirstentitus',
#  'C52BTHdxktP': 'kirstentitus',
#  'C5zLqYhvey4': 'kirstentitus',
#  'Cx631--LRIO': 'kirstentitus',
#  'CwbPyqJLeKK': 'kirstentitus',
#  'CrKGwAOLOQP': 'kirstentitus',
#  'CrEj5UfvtLQ': 'kirstentitus',
#  'CpOTEo8pVA6': 'kirstentitus',
#  'Co_EgmZP_vl': 'kirstentitus',
#  'CoyO50BJVbk': 'kirstentitus',
#  'CoN_9L_PHPc': 'kirstentitus',
#  'Cnp-prTP974': 'kirstentitus',
#  'DHgCcCaTBjT': 'imnotningning',
#  'DHYAxmnTOLF': 'imnotningning',
#  'DG8XZlEz6_P': 'imnotningning',
#  'DF67BfgTKE1': 'imnotningning',
#  'DEy-7xNTDLP': 'imnotningning',
#  'DEhF3kjTRAt': 'imnotningning',
#  'DECHxF1z3bK': 'imnotningning',
#  'DD1HcG6ziAz': 'imnotningning',
#  'DDOkvwJzwg-': 'imnotningning',
#  'DDHkcSOzG_O': 'imnotningning',
#  'DC64HPtz6S4': 'imnotningning',
#  'DCrqd-YTCNl': 'imnotningning',
#  'DCecw4vTOsy': 'imnotningning',
#  'DCd90FaTeZ3': 'imnotningning',
#  'DCcA5CATePu': 'imnotningning',
#  'DCYFegzT4hS': 'imnotningning',
#  'DCJd9amTT6t': 'imnotningning',
#  'DCG3H3VN8hw': 'imnotningning',
#  'DB8pyHhzFMs': 'imnotningning',
#  'DB3tbh6zlVL': 'imnotningning',
#  'DB1HJ1HTHtn': 'imnotningning',
#  'DBlmjnXT4Bi': 'imnotningning',
#  'DBc9QgNTeqQ': 'imnotningning',
#  'DBTn8x3zGtD': 'imnotningning',
#  'DBSURyXTS51': 'imnotningning',
#  'DBBYS2WoRsx': 'imnotningning',
#  'DA-9qOeox_K': 'imnotningning',
#  'DAnV4HnTPPd': 'imnotningning',
#  'DALRHsZTHmD': 'imnotningning',
#  'C_kbSMxzTCs': 'imnotningning',
#  'C_e-Za6TwRQ': 'imnotningning',
#  'C_c3N09zuTc': 'imnotningning',
#  'C_Z7O21zYdV': 'imnotningning',
#  'C-uNYtfz-8p': 'imnotningning',
#  'C-UkC-mzyQl': 'imnotningning',
#  'C-Uj0s2zI8d': 'imnotningning',
#  'C-SvnF2zUx3': 'imnotningning',
#  'C9yfIxLzPd-': 'imnotningning',
#  'C9nAVrZT-s5': 'imnotningning',
#  'C9MOJZXSvi3': 'imnotningning',
#  'C8_e6iySZTX': 'imnotningning',
#  'C89Q5XUyPvy': 'imnotningning',
#  'C7WMM2svJFN': 'imnotningning',
#  'C7Rg5kYPE7X': 'imnotningning',
#  'C7JXRAuP2Uy': 'imnotningning',
#  'C7EXP01v44D': 'imnotningning',
#  'C6v7HTJPAv7': 'imnotningning',
#  'C6vav8CuSNs': 'imnotningning',
#  'C6q1oHCBG53': 'imnotningning',
#  'C6OZNdpvmdL': 'imnotningning',
#  'C5qb39HPaQz': 'imnotningning',
#  'C30C8n0vY0P': 'imnotningning',
#  'C30CpSMPSf6': 'imnotningning',
#  'C3XqPV1vaS0': 'imnotningning',
#  'C3HWp5-PFA0': 'imnotningning',
#  'C3Eu6xvtC47': 'imnotningning',
#  'C2-S3o8vOJY': 'imnotningning',
#  'C2rpSjJPD2N': 'imnotningning',
#  'C131cOYBlPh': 'imnotningning',
#  'C1yzT3nBRoY': 'imnotningning',
#  'C1tD-5BBhDN': 'imnotningning',
#  'C1lr_JcBGAF': 'imnotningning',
#  'C1g7TlhBLqf': 'imnotningning',
#  'C1Lh8GFBtFl': 'imnotningning',
#  'C1LhdpSh-7L': 'imnotningning',
#  'C1LhXL-hw-A': 'imnotningning',
#  'C09AY0rhIKr': 'imnotningning',
#  'C0YlWRZrntl': 'imnotningning',
#  'C0Tag1rr_Pk': 'imnotningning',
#  'C0GhRHBLfda': 'imnotningning',
#  'CzwMqmhP37r': 'imnotningning',
#  'Czi1oqmBJzA': 'imnotningning',
#  'CzdhZ3ehCT7': 'imnotningning',
#  'CzVx3cMBZVC': 'imnotningning',
#  'CytYoCfB0iR': 'imnotningning',
#  'CyntKdKrzOj': 'imnotningning',
#  'CylkShihMYN': 'imnotningning',
#  'CyVnDicB2rZ': 'imnotningning',
#  'CwyleLehioo': 'imnotningning',
#  'Cwj9XlEOGYa': 'imnotningning',
#  'Cwj7qBwOHqs': 'imnotningning',
#  'CwbiLTEBBpB': 'imnotningning',
#  'CwR-v_Pu0qz': 'imnotningning',
#  'CwO0CNNuvPd': 'imnotningning',
#  'CwOylItOgr6': 'imnotningning',
#  'CwACXOZBdVR': 'imnotningning',
#  'Cv9QuNRBMSz': 'imnotningning',
#  'Cvoxw4uBZYu': 'imnotningning',
#  'CvfITHUhPRs': 'imnotningning',
#  'CvaLM9yhPbd': 'imnotningning',
#  'Cur1b-1BXAI': 'imnotningning',
#  'CtshHv5B1ob': 'imnotningning',
#  'Csu-h6yPcz6': 'imnotningning',
#  'Csp9_FmBAf9': 'imnotningning',
#  'CsljmN6oRtY': 'imnotningning',
#  'Csh-TUNhqWv': 'imnotningning',
#  'DIip2tlyfAB': 'aerichandesu',
#  'DIfxeTESmAH': 'aerichandesu',
#  'DIYwLgyS4w3': 'aerichandesu',
#  'DITVYkHoRQ5': 'aerichandesu',
#  'DIOVV-XylwC': 'aerichandesu',
#  'DIHGn_Qy514': 'aerichandesu',
#  'DH-e8zRSQsG': 'aerichandesu',
#  'DH5M7dcyXM6': 'aerichandesu',
#  'DHve8NGS98p': 'aerichandesu',
#  'DHnfttjypqr': 'aerichandesu',
#  'DHcmfODONUw': 'aerichandesu',
#  'DHWD3PnSB6T': 'aerichandesu',
#  'DHGGu-nNJgp': 'aerichandesu',
#  'DG_rupoz7jY': 'aerichandesu',
#  'DG3m4CgukMa': 'aerichandesu',
#  'DGw_vEwNVlZ': 'aerichandesu',
#  'DGuGdLdIEqo': 'aerichandesu',
#  'DGkRbomyzni': 'aerichandesu',
#  'DGXyq7cyWkH': 'aerichandesu',
#  'DGVH5hYSrQs': 'aerichandesu',
#  'DGSe9cUSNqP': 'aerichandesu',
#  'DGEzj7cu42b': 'aerichandesu',
#  'DGC9-ozuoy9': 'aerichandesu',
#  'DF54i8HSizy': 'aerichandesu',
#  'DFv6K7Vu1tT': 'aerichandesu',
#  'DFo3j-6y-hQ': 'aerichandesu',
#  'DFcaUoUxswe': 'aerichandesu',
#  'DFaKnRmJwwl': 'aerichandesu',
#  'DFPiiIYyjsW': 'aerichandesu',
#  'DFPhbz-yHOw': 'aerichandesu',
#  'DFPg8CiykOD': 'aerichandesu',
#  'DFPTatoSxgl': 'aerichandesu',
#  'DEwfQsMSVqB': 'aerichandesu',
#  'DEweEQ4yE6b': 'aerichandesu',
#  'DEg69dTyFoB': 'aerichandesu',
#  'DECsyC6S08S': 'aerichandesu',
#  'DD4H_CtSKdI': 'aerichandesu',
#  'DD04EGJyoxk': 'aerichandesu',
#  'DDw-G7Xy9g4': 'aerichandesu',
#  'DDoyMM8SRJE': 'aerichandesu',
#  'DDO76ScyKdo': 'aerichandesu',
#  'DDO7aO-ynmQ': 'aerichandesu',
#  'DDHdHv0y2mt': 'aerichandesu',
#  'DDEbLrEyEer': 'aerichandesu',
#  'DC9Lsb2yt4i': 'aerichandesu',
#  'DClocJMS4Zb': 'aerichandesu',
#  'DCjY7sUSxvt': 'aerichandesu',
#  'DCbWEzLyiJ1': 'aerichandesu',
#  'DCWp0aKy_nv': 'aerichandesu',
#  'DCVf82eyW1y': 'aerichandesu',
#  'DCHam0ryLtC': 'aerichandesu',
#  'DCCLtFQSSM1': 'aerichandesu',
#  'DB5ecKySC9b': 'aerichandesu',
#  'DB3OSBUS8wp': 'aerichandesu',
#  'DB1GCn3TguT': 'aerichandesu',
#  'DB0OqHxzUUK': 'aerichandesu',
#  'DBx69UmS7uc': 'aerichandesu',
#  'DBvbT7gSLnA': 'aerichandesu',
#  'DBohvM9yMna': 'aerichandesu',
#  'DBoHQe0yhMM': 'aerichandesu',
#  'DBnhsv5yl2p': 'aerichandesu',
#  'DBVDVUDzBrI': 'aerichandesu',
#  'DBTqz43Sece': 'aerichandesu',
#  'DBOP8sMS2-B': 'aerichandesu',
#  'DBNPRc7y9uv': 'aerichandesu',
#  'DBKnQtuS68U': 'aerichandesu',
#  'DBKnHZ2y32o': 'aerichandesu',
#  'DBKmbTnz9f6': 'aerichandesu',
#  'DA3fIImSztp': 'aerichandesu',
#  'DA0d2DiyzqD': 'aerichandesu',
#  'DA0cgfwSK7c': 'aerichandesu',
#  'DAsC3tQyZJy': 'aerichandesu',
#  'DAgR6M1yYRL': 'aerichandesu',
#  'DAQLHPBSqj6': 'aerichandesu',
#  'DAOcAHpS-m3': 'aerichandesu',
#  'DAG1e6GyAXI': 'aerichandesu',
#  'C_9d6MwSV-_': 'aerichandesu',
#  'C_3R1N1ScVp': 'aerichandesu',
#  'C_0bePySev4': 'aerichandesu',
#  'C_0abX8SJ_f': 'aerichandesu',
#  'C_svdlKSEKv': 'aerichandesu',
#  'C_srGxQy_vB': 'aerichandesu',
#  'C_spuFkSNYL': 'aerichandesu',
#  'C_hEBicylmq': 'aerichandesu',
#  'C_g_0g1SJkx': 'aerichandesu',
#  'C_cx0z7u2p6': 'aerichandesu',
#  'C_Xk2wASacu': 'aerichandesu',
#  'C_TkPVFzvmh': 'aerichandesu',
#  'C_H_Wtmy_32': 'aerichandesu',
#  'C_C5c45S-zA': 'aerichandesu',
#  'C-25aqYSWgl': 'aerichandesu',
#  'C-0Q8c_ypV7': 'aerichandesu',
#  'C-wpNP1yzQ8': 'aerichandesu',
#  'C-jfTS-ylP8': 'aerichandesu',
#  'C-b2vprSrGp': 'aerichandesu',
#  'C-SKtODSXK6': 'aerichandesu',
#  'C-Fyt8kSyXa': 'aerichandesu',
#  'C-BGUJcyMwD': 'aerichandesu',
#  'C9_q0qVyTGZ': 'aerichandesu',
#  'C94IoMNyR8E': 'aerichandesu',
#  'C9xDPMBSBvL': 'aerichandesu',
#  'C9xCthyyH-M': 'aerichandesu',
#  'C9xCOzoSqqK': 'aerichandesu',
#  'C9riBEHy8mo': 'aerichandesu',
#  'C9mstYhyRxB': 'aerichandesu',
#  'C9d0Cjkyed0': 'aerichandesu',
#  'C9cS7wmyWtX': 'aerichandesu',
#  'C9bRxiMSGIA': 'aerichandesu',
#  'C9M5qqtSHyC': 'aerichandesu',
#  'C9KecneS54X': 'aerichandesu',
#  'C9KZe5ZSWRf': 'aerichandesu',
#  'C9J3X4vSbQV': 'aerichandesu',
#  'C9FUVjvSmLo': 'aerichandesu',
#  'C8_OzffSsiK': 'aerichandesu',
#  'C83-VTESn5F': 'aerichandesu',
#  'C8e10DcSWye': 'aerichandesu',
#  'C8e0xw6yRyL': 'aerichandesu',
#  'C8eqJ-_SkjH': 'aerichandesu',
#  'C8USsWuyaCn': 'aerichandesu',
#  'C8RPby0S8e3': 'aerichandesu',
#  'C8PoberSN-I': 'aerichandesu',
#  'C8Jxr8qy0T1': 'aerichandesu',
#  'C7_Xn0cS1B1': 'aerichandesu',
#  'C76k-ksy1Ce': 'aerichandesu',
#  'C7oJBbdO8QX': 'aerichandesu',
#  'C7nURrBS6SO': 'aerichandesu',
#  'C7l7w-gyabz': 'aerichandesu',
#  'C7g31v-S57E': 'aerichandesu',
#  'C7g200wys3m': 'aerichandesu',
#  'C7eYebvyNSP': 'aerichandesu',
#  'C7eLmGASqAm': 'aerichandesu',
#  'C7a025kyFTj': 'aerichandesu',
#  'C7az76NyKgC': 'aerichandesu',
#  'C7ZRDx3Sxfi': 'aerichandesu',
#  'C7YsCbWuN-1': 'aerichandesu',
#  'C7UCgETStS3': 'aerichandesu',
#  'C7S19h0yoFS': 'aerichandesu',
#  'C7RL8S-yAiL': 'aerichandesu',
#  'C7JrUbIyfOd': 'aerichandesu',
#  'C7DLE5vSTKT': 'aerichandesu',
#  'C7BmMl3rgRp': 'aerichandesu',
#  'C7BjPWbLN01': 'aerichandesu',
#  'C631aHGyyuY': 'aerichandesu',
#  'C6x2rQIrdrw': 'aerichandesu',
#  'C6qkFoarh4v': 'aerichandesu',
#  'C6qhfkWLPy1': 'aerichandesu',
#  'C6qg3GKrnV5': 'aerichandesu',
#  'C6eAUtwSk9J': 'aerichandesu',
#  'C6d_0oIS6IV': 'aerichandesu',
#  'C6TpoFbSvpY': 'aerichandesu',
#  'DIdwTJZzQnQ': 'imwinter',
#  'DH4l9wJgyMR': 'imwinter',
#  'DHsRmUsTRy_': 'imwinter',
#  'DHfiziNTa2m': 'imwinter',
#  'DHKqBbyTx1L': 'imwinter',
#  'DG5iQfvzP-F': 'imwinter',
#  'DGx0hFQTuJm': 'imwinter',
#  'DF_9zzjtUFF': 'imwinter',
#  'DF1uxwOJk1-': 'imwinter',
#  'DFwu1b6TySi': 'imwinter',
#  'DFhUwA-zaJ5': 'imwinter',
#  'DFf0N1YzyR_': 'imwinter',
#  'DFfrgYSzwPn': 'imwinter',
#  'DFQAU7HzUAb': 'imwinter',
#  'DE1tP3SThM7': 'imwinter',
#  'DEhOfMoTJsD': 'imwinter',
#  'DEGe8Q1ToWj': 'imwinter',
#  'DEFOP3WT_gv': 'imwinter',
#  'DEAR-2Ozyd8': 'imwinter',
#  'DD-6i86zLVl': 'imwinter',
#  'DDv1UfATSut': 'imwinter',
#  'DDqSwt_z8nJ': 'imwinter',
#  'DCyN-bJTPBy': 'imwinter',
#  'DCjfmkHzlFT': 'imwinter',
#  'DCZRyC7zofX': 'imwinter',
#  'DCWjVQ5Tt71': 'imwinter',
#  'DB41IXOTBpN': 'imwinter',
#  'DBwEbH_zb7f': 'imwinter',
#  'DBoKdU0PQ-a': 'imwinter',
#  'DBgYggZTT8O': 'imwinter',
#  'DBf9qOfT-Ku': 'imwinter',
#  'DBdYUyUT3SE': 'imwinter',
#  'DBTqN1vTtwT': 'imwinter',
#  'DBSTFTFzILO': 'imwinter',
#  'DBDab7XThIN': 'imwinter',
#  'DA02CueTjQY': 'imwinter',
#  'DAp54wRzqn_': 'imwinter',
#  'DAgUVg_TFDp': 'imwinter',
#  'C-2i4LvP-XD': 'imwinter',
#  'DB7AzCbx-fX': 'katiefang',
#  'DE-QQvypwT8': 'asxpliu',
#  'DIbzsgWv3-D': 'erica.ha',
#  'DIZOPhRPCLF': 'erica.ha',
#  'DIWxY5oSpVa': 'erica.ha',
#  'DIROd9ExW_0': 'erica.ha',
#  'DIHkn2NtGXU': 'erica.ha',
#  'DH1M6kaRiGD': 'erica.ha',
#  'DHOrAOaxx4t': 'erica.ha',
#  'DGrGNqMpdrB': 'erica.ha',
#  'DGY_BGFyIpi': 'erica.ha',
#  'DGByiW3Sxk3': 'erica.ha',
#  ...}

# %%
import os, json, re

def build_shortcode_index(old_json_path: str) -> dict[str, str]:
    """
    Returns mapping {shortcode: account_handle} using the old data file.

    If the same shortcode appears under multiple handles, the first one wins.
    """
    index = {}
    if not os.path.exists(old_json_path):
        print(f"⚠️ old-json file '{old_json_path}' not found; cannot build account lookup.")
        return index

    with open(old_json_path) as f:
        old = json.load(f)

    pattern = re.compile(r"/p/([^/]+)/")   # capture whatever’s between '/p/' and the next '/'

    for handle, posts in old.items():
        for post_path in posts.keys():    # e.g. "/cristiano/p/DIe1T1bg2Wf/"
            m = pattern.search(post_path)
            if not m:
                continue
            code = m.group(1)              # "DIe1T1bg2Wf"
            index.setdefault(code, handle)

    print(f"🔎 Built handle-lookup for {len(index)} shortcodes")
    return index

# %% [markdown]
# ########

# %%
# Define login function
async def signon(page, username, password):
    try:
        await page.goto("https://www.instagram.com/accounts/login/", wait_until="networkidle")
        await page.wait_for_selector('input[name="username"]', timeout=10000)
        await page.fill('input[name="username"]', username)
        await page.fill('input[name="password"]', password)
        await page.wait_for_timeout(500)
        print("Hitting login button")

        # Wait until the element with the aria-label "Log in" is visible.
        await page.wait_for_selector("div[aria-label='Log in']", state="visible")
        # Now attempt a click on it.
        await page.click("div[aria-label='Log in']")

        #wait for networkidle
        await page.wait_for_load_state("networkidle")
        
        #look for this: <span class="x1lliihq x193iq5w x6ikm8r x10wlt62 xlyipyv xuxw1ft">Save info</span>
        # the button is its 5th parent
        await page.wait_for_selector("span:has-text('Save info')", timeout=15000)
        # Click the button
        await page.click("span:has-text('Save info')", timeout=5000)
        
        # await page.wait_for_load_state("networkidle")
        
        
        if "login" in page.url:
            raise ValueError("Login failed: Incorrect username or password.")
        print("✅ Successfully logged in")
    except TimeoutError:
        raise TimeoutError("Login timed out. Check credentials or network connection.")

# %%
async def _fetch_shortcode(context, handle: str, code: str,
                           idx: int, total: int):
    """
    Hits   https://www.instagram.com/{handle}/p/{code}?img_index=1
    """
    await asyncio.sleep(random.uniform(*JITTER_RANGE))

    async with GLOBAL_SEM:
        page = await context.new_page()
        try:
            async with page.expect_response(
                lambda r: "/api/v1/media/" in r.url and "/info/" in r.url,
                timeout=5_000
            ) as ri:
                url = f"https://www.instagram.com/{handle}/p/{code}?img_index=1"
                await page.goto(url)

            data = await (await ri.value).json()
            return idx, code, data

        except TimeoutError:
            print(f"⏱️ Timeout: /{handle}/p/{code}")
            return idx, code, None

        except Exception as e:
            print(f"❌ {code}: {e}")
            return idx, code, None

        finally:
            await page.close()


async def refresh_shortcodes(
    csv_path: str,
    old_json_path: str,
    output_json: str,
    context: "BrowserContext",
):
    df      = pd.read_csv(csv_path)

    print(f"🔎 Found {len(df)} shortcodes in {csv_path}")
    codes   = df["shortcode"].dropna().unique().tolist()
    total   = len(codes)
    print(f"Filtered to {total} unique shortcodes")

    # ---------- NEW: build reverse index --------------------------
    handle_by_code = build_shortcode_index(old_json_path)

    # keep previous refresh if any
    store = {}
    if os.path.exists(output_json):
        with open(output_json) as f:
            store = json.load(f)

    # ---------- FAN-OUT -------------------------------------------
    tasks = []
    skipped = 0
    for i, code in enumerate(codes, start=1):
        handle = handle_by_code.get(code)
        if not handle:
            skipped += 1
            continue                      # we don't know whose post this is
        tasks.append(
            asyncio.create_task(_fetch_shortcode(context, handle, code, i, total))
        )

    if skipped:
        print(f"⚠️  {skipped} shortcodes had no handle in old JSON and were skipped")

    # ---------- FAN-IN --------------------------------------------
    for done_count, fut in enumerate(asyncio.as_completed(tasks), start=1):
        idx, code, data = await fut
        print(f"📊 finished {done_count}/{len(tasks)}")

        if data:
            store[code] = data

    with open(output_json, "w") as f:
        json.dump(store, f, indent=2)

    print(f"✅  Saved {len(store)} refreshed posts → {output_json}")

# %%
print("Starting shortcode refresh …")
async with async_playwright() as p:
    browser = await p.chromium.launch(headless=False)
    device  = p.devices["Pixel 5"]
    context = await browser.new_context(**device)
    page    = await context.new_page()

    # (optional) cookie load / login exactly as in your old routine
    await signon(page, username, password)

    # refresh every shortcode
    await refresh_shortcodes(
        csv_path="all_instagram_data.csv",
        output_json="refreshed.json",
        old_json_path="../scraper/ig_scraperv3/json/all_instagram_data.json",
        context=context,
    )

    await browser.close()
# Out:
# Starting shortcode refresh …
# Hitting login button
# ✅ Successfully logged in
# 🔎 Found 1318 shortcodes in all_instagram_data.csv
# Filtered to 1300 unique shortcodes
# ⚠️ old-json file 'all_instagram_data.json' not found; cannot build account lookup.
# ⚠️  1300 shortcodes had no handle in old JSON and were skipped
# ✅  Saved 499 refreshed posts → refreshed.json
